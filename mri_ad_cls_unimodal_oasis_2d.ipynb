# %% [markdown]
# ### Dataset
#
# Download the 2D OASIS-3 dataset from:
#
# https://drive.google.com/drive/folders/1hzqyOthgmOmwJiMvexMjv3QJ5kgKnBcY?usp=drive_link
#
# Update the ```dataset_root``` variable below to point to the 2D dataset on your system.

# %%
# %load_ext autoreload
# %autoreload 2

dataset_root = "/mnt/f/OASIS-3-MR-Sessions-2D/"

# %%
import os
import matplotlib.pyplot as plt
import torch
import numpy as np
from sklearn.metrics import classification_report

from monai.data import decollate_batch, DataLoader, CacheDataset, ThreadDataLoader
from monai.metrics import ROCAUCMetric
from monai.networks.nets import DenseNet121
from monai.transforms import (
    Activations,
    EnsureChannelFirstd,
    Compose,
    LoadImaged,
    ScaleIntensityd,
    EnsureTyped,
    Resized,
    CropForegroundd,
    SpatialPadd,
    CastToTyped,
)
from monai.utils import set_determinism

# %%
import pandas as pd
import os
from enum import Enum
from monai.transforms import Transform

class Modality(Enum):
    MR_T1 = 1
    MR_T2 = 2
    MR_T2_STAR = 3
    MR_FLAIR = 4
    MR_TOF_MRA = 5

def create_oasis_3_unimodal_dataset(csv_path: str, dataset_root: str, modality: Modality, transform: Transform, cache_rate: float):
    train_df = pd.read_csv(csv_path, sep=";")
    train_df.fillna('', inplace=True)

    column_name = ""
    if modality == Modality.MR_T1:
        column_name = "MR T1w"
    elif modality == Modality.MR_T2:
        column_name = "MR T2w"
    elif modality == Modality.MR_T2_STAR:
        column_name = "MR T2*"
    elif modality == Modality.MR_FLAIR:
        column_name = "MR FLAIR"
    elif modality == Modality.MR_TOF_MRA:
        column_name = "MR TOF-MRA"
    else:
        assert(False)

    train_data = []
    for index, row in train_df.iterrows():
        rel_path = row[column_name]
        if not rel_path:
            continue
        image_path = os.path.join(dataset_root, rel_path)
        train_data.append({"image": image_path, "label" : row["label"]})
        
    return CacheDataset(data=train_data, transform=transform, cache_rate=cache_rate, num_workers=5, copy_cache=False)

# %%
resolution = 256
cache_rate = 0.1 # might need to change this based on the amount of memory available
batch_size = 4
modality = Modality.MR_T1

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
foreground_crop_threshold = 0.1
train_table_path = "csv/oasis/oasis_3_multimodal_train.csv"
transform = Compose([
    LoadImaged("image", image_only=True),
    EnsureChannelFirstd(keys=["image", "label"], channel_dim="no_channel"),  
    CastToTyped("label", dtype=np.float64),
    ScaleIntensityd("image"),
    CropForegroundd("image", source_key="image", select_fn=lambda x: x > foreground_crop_threshold, margin=5),
    Resized(keys=["image"], spatial_size=resolution, size_mode="longest"),
    SpatialPadd(keys=["image"], spatial_size=(resolution, resolution)),
    EnsureTyped("image", device=device),
    ]
)

# TODO: fix the following files
# TODO: skip them in the dataset
'''
torch.Size([96, 96, 26])
Error transforming file: /mnt/f/OASIS-3-MR-Sessions-2D/OAS30033_MR_d0133/anat5/NIFTI/sub-OAS30033_ses-d0133_run-02_T2w.nii.gz

torch.Size([64, 64, 105])
Error transforming file: /mnt/f/OASIS-3-MR-Sessions-2D/OAS31065_MR_d0044/anat7/NIFTI/sub-OAS31065_ses-d0044_echo-1_run-02_FLAIR.nii.gz
'''

train_ds = create_oasis_3_unimodal_dataset(csv_path=train_table_path, dataset_root=dataset_root, modality=modality, transform=transform, cache_rate=cache_rate)
train_loader = ThreadDataLoader(train_ds, num_workers=0, batch_size=batch_size, shuffle=True)

val_table_path = "csv/oasis/oasis_3_multimodal_val.csv"
val_ds = create_oasis_3_unimodal_dataset(csv_path=val_table_path, dataset_root=dataset_root, modality=modality, transform=transform, cache_rate=cache_rate)
val_loader = ThreadDataLoader(val_ds, num_workers=0, batch_size=batch_size, shuffle=True)
# Out:
# Loading dataset: 100%|██████████| 254/254 [00:10<00:00, 24.08it/s]
# Loading dataset: 100%|██████████| 28/28 [00:01<00:00, 27.96it/s]

# %%
dataiter = iter(train_loader)
batch_sample = next(dataiter)
images = batch_sample["image"]
labels = batch_sample["label"]

classes = ["HC", "AD"]

plt.figure(figsize=(20, 12))
i = 0
for sample_data, sample_label in zip(images, labels):
    sample = sample_data.cpu()[0]
    plt.subplot(1, batch_size, i+1)  # Create a subplot for each sample
    plt.imshow(sample.T, cmap='gray', origin='lower')
    plt.title(f"{classes[int(sample_label.cpu()[0])]}")  # Display the label as the title
    i += 1
plt.show()

# %% [markdown]
# ### Define network and optimizer

# %%
model = DenseNet121(spatial_dims=2, in_channels=1, out_channels=1).to(device)
loss_function = torch.nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), 1e-5)
scaler = torch.cuda.amp.GradScaler()
max_epochs = 8
val_interval = 1
auc_metric = ROCAUCMetric()
out_model_dir = "./pretrained/"
model_file_name = f"DenseNet121_ad_cls_oasis_3_{str(modality).split('.')[1]}.pth"
model_file_name
# Out:
# 'DenseNet121_ad_cls_oasis_3_MR_TOF_MRA.pth'

# %% [markdown]
# ### Training

# %%
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = []
metric_values = []

y_pred_trans = Compose([Activations(sigmoid=True)])

for epoch in range(max_epochs):
    print("-" * 10)
    print(f"epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step += 1
        inputs, labels = batch_data["image"].to(device), batch_data["label"].to(device)
        optimizer.zero_grad()
        with torch.cuda.amp.autocast():
            outputs = model(inputs)
            loss = loss_function(outputs, labels)
        
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        epoch_loss += loss.item()
        print(f"{step}/{len(train_ds) // train_loader.batch_size}, " f"train_loss: {loss.item():.4f}")
        epoch_len = len(train_ds) // train_loader.batch_size
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    if (epoch + 1) % val_interval == 0:
        model.eval()
        with torch.no_grad():
            y_pred = torch.tensor([], dtype=torch.float32, device=device)
            y = torch.tensor([], dtype=torch.long, device=device)
            for val_data in val_loader:
                val_images, val_labels = (
                    val_data["image"].to(device),
                    val_data["label"].to(device),
                )
                y_pred = torch.cat([y_pred, model(val_images)], dim=0)
                y = torch.cat([y, val_labels], dim=0)
            y_onehot = torch.cat([i for i in decollate_batch(y, detach=False)], dim=0)
            y_pred_act = torch.cat([y_pred_trans(i) for i in decollate_batch(y_pred)], dim=0)
            auc_metric(y_pred_act, y_onehot)
            result = auc_metric.aggregate()
            auc_metric.reset()
            metric_values.append(result)
            acc_value = torch.eq((y_pred_act > 0.5).long(), y)
            acc_metric = acc_value.float().mean().item()
            del y_pred_act, y_onehot
            if result > best_metric:
                best_metric = result
                best_metric_epoch = epoch + 1
                torch.save(model.state_dict(), os.path.join(out_model_dir, model_file_name))
                print("saved new best metric model")
            print(
                f"current epoch: {epoch + 1} current AUC: {result:.4f}"
                f" current accuracy: {acc_metric:.4f}"
                f" best AUC: {best_metric:.4f}"
                f" at epoch: {best_metric_epoch}"
            )

print(f"train completed, best_metric (AUC): {best_metric:.4f} " f"at epoch: {best_metric_epoch}")
# Out:
# ----------
# epoch 1/8
# 1/43, train_loss: 0.5772
# 2/43, train_loss: 0.5583
# 3/43, train_loss: 0.6149
# 4/43, train_loss: 0.5474
# 5/43, train_loss: 0.5347
# 6/43, train_loss: 0.6521
# 7/43, train_loss: 0.5474
# 8/43, train_loss: 0.5654
# 9/43, train_loss: 0.5980
# 10/43, train_loss: 0.5149
# 11/43, train_loss: 0.5820
# 12/43, train_loss: 0.5100
# 13/43, train_loss: 0.6102
# 14/43, train_loss: 0.5460
# 15/43, train_loss: 0.5647
# 16/43, train_loss: 0.5794
# 17/43, train_loss: 0.6499
# 18/43, train_loss: 0.6034
# 19/43, train_loss: 0.5517
# 20/43, train_loss: 0.4879
# 21/43, train_loss: 0.5155
# 22/43, train_loss: 0.5120
# 23/43, train_loss: 0.5104
# 24/43, train_loss: 0.5428
# 25/43, train_loss: 0.5058
# 26/43, train_loss: 0.5012
# 27/43, train_loss: 0.5046
# 28/43, train_loss: 0.5032
# 29/43, train_loss: 0.4657
# 30/43, train_loss: 0.4966
# 31/43, train_loss: 0.4631
# 32/43, train_loss: 0.5215
# 33/43, train_loss: 0.6189
# 34/43, train_loss: 0.5238
# 35/43, train_loss: 0.5590
# 36/43, train_loss: 0.5900
# 37/43, train_loss: 0.4849
# 38/43, train_loss: 0.5214
# 39/43, train_loss: 0.4494
# 40/43, train_loss: 0.5541
# 41/43, train_loss: 0.4802
# 42/43, train_loss: 0.5837
# 43/43, train_loss: 0.4749
# 44/43, train_loss: 0.5838
# epoch 1 average loss: 0.5423
# saved new best metric model
# current epoch: 1 current AUC: 0.6008 current accuracy: 0.8391 best AUC: 0.6008 at epoch: 1
# ----------
# epoch 2/8
# 1/43, train_loss: 0.5063
# 2/43, train_loss: 0.4307
# 3/43, train_loss: 0.4976
# 4/43, train_loss: 0.4665
# 5/43, train_loss: 0.4919
# 6/43, train_loss: 0.4789
# 7/43, train_loss: 0.5532
# 8/43, train_loss: 0.4575
# 9/43, train_loss: 0.5360
# 10/43, train_loss: 0.4475
# 11/43, train_loss: 0.4944
# 12/43, train_loss: 0.5492
# 13/43, train_loss: 0.5269
# 14/43, train_loss: 0.4531
# 15/43, train_loss: 0.4782
# 16/43, train_loss: 0.4982
# 17/43, train_loss: 0.4764
# 18/43, train_loss: 0.4497
# 19/43, train_loss: 0.4476
# 20/43, train_loss: 0.5217
# 21/43, train_loss: 0.4023
# 22/43, train_loss: 0.4717
# 23/43, train_loss: 0.5149
# 24/43, train_loss: 0.3970
# 25/43, train_loss: 0.5345
# 26/43, train_loss: 0.4343
# 27/43, train_loss: 0.5645
# 28/43, train_loss: 0.4195
# 29/43, train_loss: 0.5220
# 30/43, train_loss: 0.5909
# 31/43, train_loss: 0.5265
# 32/43, train_loss: 0.4343
# 33/43, train_loss: 0.3846
# 34/43, train_loss: 0.4264
# 35/43, train_loss: 0.4265
# 36/43, train_loss: 0.4640
# 37/43, train_loss: 0.4813
# 38/43, train_loss: 0.4235
# 39/43, train_loss: 0.5087
# 40/43, train_loss: 0.4481
# 41/43, train_loss: 0.5149
# 42/43, train_loss: 0.5216
# 43/43, train_loss: 0.4095
# 44/43, train_loss: 0.3682
# epoch 2 average loss: 0.4762
# current epoch: 2 current AUC: 0.5607 current accuracy: 0.8391 best AUC: 0.6008 at epoch: 1
# ----------
# epoch 3/8
# 1/43, train_loss: 0.3687
# 2/43, train_loss: 0.4982
# 3/43, train_loss: 0.4382
# 4/43, train_loss: 0.5393
# 5/43, train_loss: 0.5399
# 6/43, train_loss: 0.4048
# 7/43, train_loss: 0.3548
# 8/43, train_loss: 0.5502
# 9/43, train_loss: 0.4898
# 10/43, train_loss: 0.4426
# 11/43, train_loss: 0.4111
# 12/43, train_loss: 0.5249
# 13/43, train_loss: 0.3987
# 14/43, train_loss: 0.4991
# 15/43, train_loss: 0.5379
# 16/43, train_loss: 0.5586
# 17/43, train_loss: 0.3474
# 18/43, train_loss: 0.4327
# 19/43, train_loss: 0.4436
# 20/43, train_loss: 0.6001
# 21/43, train_loss: 0.5089
# 22/43, train_loss: 0.4860
# 23/43, train_loss: 0.4338
# 24/43, train_loss: 0.4843
# 25/43, train_loss: 0.4947
# 26/43, train_loss: 0.4061
# 27/43, train_loss: 0.3400
# 28/43, train_loss: 0.3706
# 29/43, train_loss: 0.3351
# 30/43, train_loss: 0.4849
# 31/43, train_loss: 0.3344
# 32/43, train_loss: 0.3304
# 33/43, train_loss: 0.3285
# 34/43, train_loss: 0.4374
# 35/43, train_loss: 0.3712
# 36/43, train_loss: 0.4374
# 37/43, train_loss: 0.4223
# 38/43, train_loss: 0.3865
# 39/43, train_loss: 0.3717
# 40/43, train_loss: 0.4121
# 41/43, train_loss: 0.4323
# 42/43, train_loss: 0.3914
# 43/43, train_loss: 0.3705
# 44/43, train_loss: 0.3185
# epoch 3 average loss: 0.4334
# current epoch: 3 current AUC: 0.5763 current accuracy: 0.8391 best AUC: 0.6008 at epoch: 1
# ----------
# epoch 4/8
# 1/43, train_loss: 0.4205
# 2/43, train_loss: 0.4875
# 3/43, train_loss: 0.3146
# 4/43, train_loss: 0.4209
# 5/43, train_loss: 0.4131
# 6/43, train_loss: 0.4115
# 7/43, train_loss: 0.4248
# 8/43, train_loss: 0.3728
# 9/43, train_loss: 0.3583
# 10/43, train_loss: 0.3469
# 11/43, train_loss: 0.3051
# 12/43, train_loss: 0.4734
# 13/43, train_loss: 0.3025
# 14/43, train_loss: 0.5468
# 15/43, train_loss: 0.4775
# 16/43, train_loss: 0.4033
# 17/43, train_loss: 0.5872
# 18/43, train_loss: 0.3928
# 19/43, train_loss: 0.3973
# 20/43, train_loss: 0.4619
# 21/43, train_loss: 0.4146
# 22/43, train_loss: 0.5983
# 23/43, train_loss: 0.4491
# 24/43, train_loss: 0.2945
# 25/43, train_loss: 0.4152
# 26/43, train_loss: 0.5002
# 27/43, train_loss: 0.4737
# 28/43, train_loss: 0.4260
# 29/43, train_loss: 0.3478
# 30/43, train_loss: 0.3850
# 31/43, train_loss: 0.4147
# 32/43, train_loss: 0.3523
# 33/43, train_loss: 0.4556
# 34/43, train_loss: 0.4997
# 35/43, train_loss: 0.4106
# 36/43, train_loss: 0.2831
# 37/43, train_loss: 0.2829
# 38/43, train_loss: 0.3925
# 39/43, train_loss: 0.2749
# 40/43, train_loss: 0.3945
# 41/43, train_loss: 0.3358
# 42/43, train_loss: 0.4029
# 43/43, train_loss: 0.3369
# 44/43, train_loss: 0.2864
# epoch 4 average loss: 0.4033
# saved new best metric model
# current epoch: 4 current AUC: 0.6155 current accuracy: 0.8391 best AUC: 0.6155 at epoch: 4
# ----------
# epoch 5/8
# 1/43, train_loss: 0.2763
# 2/43, train_loss: 0.3398
# 3/43, train_loss: 0.3908
# 4/43, train_loss: 0.2756
# 5/43, train_loss: 0.4648
# 6/43, train_loss: 0.4085
# 7/43, train_loss: 0.4523
# 8/43, train_loss: 0.3824
# 9/43, train_loss: 0.4760
# 10/43, train_loss: 0.4009
# 11/43, train_loss: 0.4212
# 12/43, train_loss: 0.3957
# 13/43, train_loss: 0.3881
# 14/43, train_loss: 0.2573
# 15/43, train_loss: 0.3109
# 16/43, train_loss: 0.4488
# 17/43, train_loss: 0.4092
# 18/43, train_loss: 0.4586
# 19/43, train_loss: 0.2546
# 20/43, train_loss: 0.4556
# 21/43, train_loss: 0.3773
# 22/43, train_loss: 0.4715
# 23/43, train_loss: 0.5277
# 24/43, train_loss: 0.3173
# 25/43, train_loss: 0.3078
# 26/43, train_loss: 0.3183
# 27/43, train_loss: 0.3252
# 28/43, train_loss: 0.3594
# 29/43, train_loss: 0.5484
# 30/43, train_loss: 0.2555
# 31/43, train_loss: 0.3078
# 32/43, train_loss: 0.4741
# 33/43, train_loss: 0.5178
# 34/43, train_loss: 0.2485
# 35/43, train_loss: 0.4030
# 36/43, train_loss: 0.2536
# 37/43, train_loss: 0.5127
# 38/43, train_loss: 0.3087
# 39/43, train_loss: 0.4301
# 40/43, train_loss: 0.3619
# 41/43, train_loss: 0.3083
# 42/43, train_loss: 0.3887
# 43/43, train_loss: 0.3769
# 44/43, train_loss: 0.5114
# epoch 5 average loss: 0.3836
# current epoch: 5 current AUC: 0.6076 current accuracy: 0.8391 best AUC: 0.6155 at epoch: 4
# ----------
# epoch 6/8
# 1/43, train_loss: 0.3670
# 2/43, train_loss: 0.5300
# 3/43, train_loss: 0.5132
# 4/43, train_loss: 0.2987
# 5/43, train_loss: 0.3759
# 6/43, train_loss: 0.3056
# 7/43, train_loss: 0.4231
# 8/43, train_loss: 0.3020
# 9/43, train_loss: 0.3348
# 10/43, train_loss: 0.2423
# 11/43, train_loss: 0.3125
# 12/43, train_loss: 0.3745
# 13/43, train_loss: 0.4956
# 14/43, train_loss: 0.3057
# 15/43, train_loss: 0.3259
# 16/43, train_loss: 0.2946
# 17/43, train_loss: 0.3228
# 18/43, train_loss: 0.4542
# 19/43, train_loss: 0.3533
# 20/43, train_loss: 0.3584
# 21/43, train_loss: 0.3020
# 22/43, train_loss: 0.3233
# 23/43, train_loss: 0.4701
# 24/43, train_loss: 0.3478
# 25/43, train_loss: 0.3664
# 26/43, train_loss: 0.3002
# 27/43, train_loss: 0.3054
# 28/43, train_loss: 0.3622
# 29/43, train_loss: 0.5709
# 30/43, train_loss: 0.3672
# 31/43, train_loss: 0.3488
# 32/43, train_loss: 0.2228
# 33/43, train_loss: 0.4495
# 34/43, train_loss: 0.3062
# 35/43, train_loss: 0.4429
# 36/43, train_loss: 0.3567
# 37/43, train_loss: 0.4402
# 38/43, train_loss: 0.3064
# 39/43, train_loss: 0.2248
# 40/43, train_loss: 0.4473
# 41/43, train_loss: 0.2672
# 42/43, train_loss: 0.5099
# 43/43, train_loss: 0.3096
# 44/43, train_loss: 0.8354
# epoch 6 average loss: 0.3744
# saved new best metric model
# current epoch: 6 current AUC: 0.6184 current accuracy: 0.8391 best AUC: 0.6184 at epoch: 6
# ----------
# epoch 7/8
# 1/43, train_loss: 0.2210
# 2/43, train_loss: 0.3818
# 3/43, train_loss: 0.3525
# 4/43, train_loss: 0.3775
# 5/43, train_loss: 0.3539
# 6/43, train_loss: 0.4375
# 7/43, train_loss: 0.2241
# 8/43, train_loss: 0.3414
# 9/43, train_loss: 0.2862
# 10/43, train_loss: 0.3218
# 11/43, train_loss: 0.2840
# 12/43, train_loss: 0.4930
# 13/43, train_loss: 0.2963
# 14/43, train_loss: 0.2813
# 15/43, train_loss: 0.4208
# 16/43, train_loss: 0.4098
# 17/43, train_loss: 0.2198
# 18/43, train_loss: 0.3609
# 19/43, train_loss: 0.2940
# 20/43, train_loss: 0.2760
# 21/43, train_loss: 0.3636
# 22/43, train_loss: 0.4432
# 23/43, train_loss: 0.3650
# 24/43, train_loss: 0.3652
# 25/43, train_loss: 0.2925
# 26/43, train_loss: 0.2262
# 27/43, train_loss: 0.4412
# 28/43, train_loss: 0.2880
# 29/43, train_loss: 0.2094
# 30/43, train_loss: 0.4337
# 31/43, train_loss: 0.4686
# 32/43, train_loss: 0.3825
# 33/43, train_loss: 0.2107
# 34/43, train_loss: 0.4440
# 35/43, train_loss: 0.5244
# 36/43, train_loss: 0.3679
# 37/43, train_loss: 0.4538
# 38/43, train_loss: 0.3755
# 39/43, train_loss: 0.3883
# 40/43, train_loss: 0.4605
# 41/43, train_loss: 0.4220
# 42/43, train_loss: 0.3443
# 43/43, train_loss: 0.2742
# 44/43, train_loss: 0.5193
# epoch 7 average loss: 0.3568
# current epoch: 7 current AUC: 0.6115 current accuracy: 0.8391 best AUC: 0.6184 at epoch: 6
# ----------
# epoch 8/8
# 1/43, train_loss: 0.2646
# 2/43, train_loss: 0.3511
# 3/43, train_loss: 0.3386
# 4/43, train_loss: 0.4962
# 5/43, train_loss: 0.5092
# 6/43, train_loss: 0.2030
# 7/43, train_loss: 0.4418
# 8/43, train_loss: 0.4098
# 9/43, train_loss: 0.1988
# 10/43, train_loss: 0.4900
# 11/43, train_loss: 0.2987
# 12/43, train_loss: 0.3383
# 13/43, train_loss: 0.2940
# 14/43, train_loss: 0.5070
# 15/43, train_loss: 0.6223
# 16/43, train_loss: 0.4275
# 17/43, train_loss: 0.3251
# 18/43, train_loss: 0.3454
# 19/43, train_loss: 0.4020
# 20/43, train_loss: 0.2741
# 21/43, train_loss: 0.3613
# 22/43, train_loss: 0.2868
# 23/43, train_loss: 0.2670
# 24/43, train_loss: 0.3699
# 25/43, train_loss: 0.2800
# 26/43, train_loss: 0.3541
# 27/43, train_loss: 0.3162
# 28/43, train_loss: 0.3748
# 29/43, train_loss: 0.4169
# 30/43, train_loss: 0.2582
# 31/43, train_loss: 0.5085
# 32/43, train_loss: 0.3151
# 33/43, train_loss: 0.2703
# 34/43, train_loss: 0.2629
# 35/43, train_loss: 0.2025
# 36/43, train_loss: 0.2007
# 37/43, train_loss: 0.3593
# 38/43, train_loss: 0.3446
# 39/43, train_loss: 0.2691
# 40/43, train_loss: 0.1964
# 41/43, train_loss: 0.2540
# 42/43, train_loss: 0.3131
# 43/43, train_loss: 0.3394
# 44/43, train_loss: 0.1998
# epoch 8 average loss: 0.3377
# saved new best metric model
# current epoch: 8 current AUC: 0.6262 current accuracy: 0.8391 best AUC: 0.6262 at epoch: 8
# train completed, best_metric (AUC): 0.6262 at epoch: 8
