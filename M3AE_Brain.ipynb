# %%
# !pip install -U openmim
# !mim install mmcv
# !pip install SimpleITK
# !pip install monai
# !pip install --upgrade --index-url https://pypi.ngc.nvidia.com nvidia-tensorrt
# Out:
# ...
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# ...
# Looking in indexes: https://pypi.ngc.nvidia.com
# ...

# %%
import os
path="/content/drive/My Drive/MLMI/model/m3ae"
os.chdir(path)
os.listdir(path)
# !python pretrain.py
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# Reading file from path: /content/drive/My Drive/MLMI/dataset/2-MICCAI_BraTS_2018/MICCAI_BraTS_2018_Data_Training/HGG/Brats18_TCIA02_117_1/Brats18_TCIA02_117_1_t1.nii.gz
# Reading file from path: /content/drive/My Drive/MLMI/dataset/2-MICCAI_BraTS_2018/MICCAI_BraTS_2018_Data_Training/HGG/Brats18_TCIA02_117_1/Brats18_TCIA02_117_1_t1ce.nii.gz
# Reading file from path: /content/drive/My Drive/MLMI/dataset/2-MICCAI_BraTS_2018/MICCAI_BraTS_2018_Data_Training/HGG/Brats18_TCIA02_117_1/Brats18_TCIA02_117_1_t2.nii.gz
# Reading file from path: /content/drive/My Drive/MLMI/dataset/2-MICCAI_BraTS_2018/MICCAI_BraTS_2018_Data_Training/HGG/Brats18_TCIA02_117_1/Brats18_TCIA02_117_1_flair.nii.gz
# Reading file from path: /content/drive/My Drive/MLMI/dataset/2-MICCAI_BraTS_2018/MICCAI_BraTS_2018_Data_Training/HGG/Brats18_TCIA02_117_1/Brats18_TCIA02_117_1_seg.nii.gz
# train Epoch: [142][ 60/114]	Time  0.395 ( 0.455)	Data  0.004 ( 0.052)	Loss 1.3207e-02 (1.2560e-02)
# ...
