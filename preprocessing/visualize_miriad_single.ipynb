# %% [markdown]
# # Raw Scans

# %%
# %load_ext autoreload
# %autoreload 2

from vis_util import visualize_structural_mri_session

visualize_structural_mri_session("../data/miriad/miriad_188_AD_M", axis=2, limit=5)
visualize_structural_mri_session("../data/miriad/miriad_188_AD_M", axis=1, limit=5)
visualize_structural_mri_session("../data/miriad/miriad_188_AD_M", axis=0, limit=5)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # MONAI Pipeline

# %%
visualize_structural_mri_session("../data/mirad-monai/miriad_188_AD_M", axis=2, limit=5)
visualize_structural_mri_session("../data/mirad-monai/miriad_188_AD_M", axis=1, limit=5)
visualize_structural_mri_session("../data/mirad-monai/miriad_188_AD_M", axis=0, limit=5)
