# %% [markdown]
# # Raw Scans

# %%
# %load_ext autoreload
# %autoreload 2

from preprocessing.vis_util import visualize_structural_mri_session

visualize_structural_mri_session("../data/miriad/miriad_201_AD_F", axis=2)
visualize_structural_mri_session("../data/miriad/miriad_201_AD_F", axis=1)
visualize_structural_mri_session("../data/miriad/miriad_201_AD_F", axis=0)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # MONAI Pipeline
