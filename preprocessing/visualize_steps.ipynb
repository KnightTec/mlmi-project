# %% [markdown]
# # 1. Raw MR Scans

# %%
# %load_ext autoreload
# %autoreload 2

from oasis_util import visualize_structural_mri_session

visualize_structural_mri_session("../data/oasis-3/OAS30001_MR_d0129/")
visualize_structural_mri_session("../data/oasis-3/OAS30001_MR_d0757/")
visualize_structural_mri_session("../data/oasis-3/OAS30001_MR_d2430/")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
visualize_structural_mri_session("../data/oasis-3-proc-1/OAS30001_MR_d0129/")
visualize_structural_mri_session("../data/oasis-3-proc-1/OAS30001_MR_d0757/")
visualize_structural_mri_session("../data/oasis-3-proc-1/OAS30001_MR_d2430/")
