# %% [markdown]
# # 1. Raw MR Scans

# %%
# %load_ext autoreload
# %autoreload 2

from vis_util import visualize_structural_mri_session

visualize_structural_mri_session("../data/ixi-sessions/IXI002-Guys-0828/")
visualize_structural_mri_session("../data/ixi-sessions/IXI012-HH-1211/")
visualize_structural_mri_session("../data/ixi-sessions/IXI013-HH-1212/")
visualize_structural_mri_session("../data/ixi-sessions/IXI014-HH-1236/")
visualize_structural_mri_session("../data/ixi-sessions/IXI015-HH-1258/")
visualize_structural_mri_session("../data/ixi-sessions/IXI016-Guys-0697/")
visualize_structural_mri_session("../data/ixi-sessions/IXI017-Guys-0698/")
visualize_structural_mri_session("../data/ixi-sessions/IXI019-Guys-0702/")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1.1 Raw Scans with only 99.95 percentile of MRA data

# %%
# %load_ext autoreload
# %autoreload 2

from vis_util import visualize_structural_mri_session

visualize_structural_mri_session("../data/ixi-sessions/IXI002-Guys-0828/", val_percentile=99.95)
visualize_structural_mri_session("../data/ixi-sessions/IXI012-HH-1211/", val_percentile=99.95)
visualize_structural_mri_session("../data/ixi-sessions/IXI013-HH-1212/", val_percentile=99.95)
visualize_structural_mri_session("../data/ixi-sessions/IXI014-HH-1236/", val_percentile=99.95)
visualize_structural_mri_session("../data/ixi-sessions/IXI015-HH-1258/", val_percentile=99.95)
visualize_structural_mri_session("../data/ixi-sessions/IXI016-Guys-0697/", val_percentile=99.95)
visualize_structural_mri_session("../data/ixi-sessions/IXI017-Guys-0698/", val_percentile=99.95)
visualize_structural_mri_session("../data/ixi-sessions/IXI019-Guys-0702/", val_percentile=99.95)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 2. MONAI Pipeline
#
# - Reorientation to LPS
# - Resampling to T1w
# - Isotropic Resampling
# - Foreground Cropping
