# %%
# %load_ext autoreload
# %autoreload 2

from vis_util import visualize_structural_mri_session

visualize_structural_mri_session("../data/oasis-3-strip-2/OAS30184_MR_d0876/", axis=2, slice_fraction=0.65)
visualize_structural_mri_session("../data/OAS30184_MR_d0876_regt1/", axis=2, slice_fraction=0.65)
visualize_structural_mri_session("../data/oasis-3-strip-2/OAS30184_MR_d0876/", axis=1)
visualize_structural_mri_session("../data/OAS30184_MR_d0876_regt1/", axis=1)
visualize_structural_mri_session("../data/oasis-3-strip-2/OAS30184_MR_d0876/", axis=0)
visualize_structural_mri_session("../data/OAS30184_MR_d0876_regt1/", axis=0)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
