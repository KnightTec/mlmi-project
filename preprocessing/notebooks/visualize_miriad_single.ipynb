# %% [markdown]
# # Raw Scans

# %%
# %load_ext autoreload
# %autoreload 2

from vis_util import visualize_structural_mri_session

visualize_structural_mri_session("../data/miriad/miriad_188_AD_M", axis=2, limit=5)
visualize_structural_mri_session("../data/miriad/miriad_188_AD_M", axis=1, limit=5)
visualize_structural_mri_session("../data/miriad/miriad_188_AD_M", axis=0, limit=5)

# %% [markdown]
# # MONAI Pipeline

# %%
visualize_structural_mri_session("../data/miriad-monai-1/miriad_188_AD_M", axis=2, limit=5, slice_fraction=0.6)
visualize_structural_mri_session("../data/miriad-monai-1/miriad_188_AD_M", axis=1, limit=5)
visualize_structural_mri_session("../data/miriad-monai-1/miriad_188_AD_M", axis=0, limit=5)

# %% [markdown]
# # Stripped

# %%
visualize_structural_mri_session("../data/miriad-strip-2/miriad_188_AD_M", axis=2, limit=5, slice_fraction=0.6)
visualize_structural_mri_session("../data/miriad-strip-2/miriad_188_AD_M", axis=1, limit=5)
visualize_structural_mri_session("../data/miriad-strip-2/miriad_188_AD_M", axis=0, limit=5)

# %% [markdown]
# # Final

# %%
# %load_ext autoreload
# %autoreload 2

from vis_util import visualize_structural_mri_session

visualize_structural_mri_session("../data/miriad-final-3/miriad_188_AD_M", axis=2, limit=5)
visualize_structural_mri_session("../data/miriad-final-3/miriad_188_AD_M", axis=1, limit=5)
visualize_structural_mri_session("../data/miriad-final-3/miriad_188_AD_M", axis=0, limit=5)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
