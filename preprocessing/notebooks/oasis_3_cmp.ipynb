# %%
# %load_ext autoreload
# %autoreload 2

from vis_util import visualize_structural_mri_session

visualize_structural_mri_session("../data/oasis-3-before/OAS30001_MR_d2430/", slice_fraction=0.5)
visualize_structural_mri_session("../data/oasis-3-before/OAS30003_MR_d3731/", slice_fraction=0.5)
visualize_structural_mri_session("../data/oasis-3-before/OAS30005_MR_d3453/", slice_fraction=0.5)
visualize_structural_mri_session("../data/oasis-3-before/OAS30008_MR_d1327/", slice_fraction=0.5)
#visualize_structural_mri_session("../data/oasis-3-strip-2/OAS30184_MR_d0876/", slice_fraction=0.65)
#visualize_structural_mri_session("../data/oasis-3-strip-2/OAS30250_MR_d1233/", slice_fraction=0.65)
#visualize_structural_mri_session("../data/oasis-3-strip-2/OAS30636_MR_d2289/", slice_fraction=0.65)
#visualize_structural_mri_session("../data/oasis-3-strip-2/OAS31372_MR_d1245/", slice_fraction=0.65)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [('../data/oasis-3-before/OAS30001_MR_d2430/anat3/sub-OAS30001_ses-d2430_FLAIR.nii.gz', 'sub-OAS30001_ses-d2430_FLAIR.nii.gz'), ('../data/oasis-3-before/OAS30001_MR_d2430/anat4/sub-OAS30001_ses-d2430_T1w.nii.gz', 'sub-OAS30001_ses-d2430_T1w.nii.gz'), ('../data/oasis-3-before/OAS30001_MR_d2430/anat5/sub-OAS30001_ses-d2430_T2star.nii.gz', 'sub-OAS30001_ses-d2430_T2star.nii.gz'), ('../data/oasis-3-before/OAS30001_MR_d2430/anat1/sub-OAS30001_ses-d2430_acq-TOF_angio.nii.gz', 'sub-OAS30001_ses-d2430_acq-TOF_angio.nii.gz'), ('../data/oasis-3-before/OAS30001_MR_d2430/anat2/sub-OAS30001_ses-d2430_acq-TSE_T2w.nii.gz', 'sub-OAS30001_ses-d2430_acq-TSE_T2w.nii.gz')]
# ...

# %%
# %load_ext autoreload
# %autoreload 2

from vis_util import visualize_structural_mri_session

visualize_structural_mri_session("../data/oasis-3-after/OAS30001_MR_d2430/", slice_fraction=0.5)
visualize_structural_mri_session("../data/oasis-3-after/OAS30003_MR_d3731/", slice_fraction=0.5)
visualize_structural_mri_session("../data/oasis-3-after/OAS30005_MR_d3453/", slice_fraction=0.5)
visualize_structural_mri_session("../data/oasis-3-after/OAS30008_MR_d1327/", slice_fraction=0.5)
#visualize_structural_mri_session("../data/oasis-3-strip-2/OAS30184_MR_d0876/", slice_fraction=0.65)
#visualize_structural_mri_session("../data/oasis-3-strip-2/OAS30250_MR_d1233/", slice_fraction=0.65)
#visualize_structural_mri_session("../data/oasis-3-strip-2/OAS30636_MR_d2289/", slice_fraction=0.65)
#visualize_structural_mri_session("../data/oasis-3-strip-2/OAS31372_MR_d1245/", slice_fraction=0.65)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
