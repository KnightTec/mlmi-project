# %%
# %load_ext autoreload
# %autoreload 2

from vis_util import visualize_structural_mri_session

visualize_structural_mri_session("../data/brats_2021/TrainingData/BraTS2021_00000/", slice_fraction=0.65)
visualize_structural_mri_session("../data/brats_2021/TrainingData/BraTS2021_00000/", axis=1)
visualize_structural_mri_session("../data/brats_2021/TrainingData/BraTS2021_00000/", axis=0)
