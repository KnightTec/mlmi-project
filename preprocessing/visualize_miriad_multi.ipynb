# %% [markdown]
# # Raw Scans

# %%
# %load_ext autoreload
# %autoreload 2

from vis_util import visualize_structural_mri_session

visualize_structural_mri_session("../data/miriad/miriad_188_AD_M", axis=2, limit=8)
visualize_structural_mri_session("../data/miriad/miriad_189_AD_M", axis=2, limit=8)
visualize_structural_mri_session("../data/miriad/miriad_190_AD_M", axis=2, limit=8)
visualize_structural_mri_session("../data/miriad/miriad_191_AD_F", axis=2, limit=8)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # MONAI Pipeline

# %%
visualize_structural_mri_session("../data/miriad-monai-1/miriad_188_AD_M", axis=2, limit=8, slice_fraction=0.65)
visualize_structural_mri_session("../data/miriad-monai-1/miriad_189_AD_M", axis=2, limit=8, slice_fraction=0.65)
visualize_structural_mri_session("../data/miriad-monai-1/miriad_190_AD_M", axis=2, limit=8, slice_fraction=0.65)
visualize_structural_mri_session("../data/miriad-monai-1/miriad_191_AD_F", axis=2, limit=8, slice_fraction=0.65)

# %% [markdown]
# # Stripped

# %%
visualize_structural_mri_session("../data/miriad-strip-2/", axis=2, limit=8, slice_fraction=0.65)
