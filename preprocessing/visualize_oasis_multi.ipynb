# %% [markdown]
# # 1. Raw MR Scans

# %%
# %load_ext autoreload
# %autoreload 2

from vis_util import visualize_structural_mri_session

visualize_structural_mri_session("../data/oasis-3/OAS30001_MR_d0129/")
visualize_structural_mri_session("../data/oasis-3/OAS30001_MR_d0757/")
visualize_structural_mri_session("../data/oasis-3/OAS30001_MR_d2430/")
visualize_structural_mri_session("../data/oasis-3/OAS30002_MR_d0371/")
visualize_structural_mri_session("../data/oasis-3/OAS30184_MR_d0876/")
visualize_structural_mri_session("../data/oasis-3/OAS30250_MR_d1233/")
visualize_structural_mri_session("../data/oasis-3/OAS30636_MR_d2289/")
visualize_structural_mri_session("../data/oasis-3/OAS31372_MR_d1245/")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Visualize SRI-24 Template

# %%
# %load_ext autoreload
# %autoreload 2

from vis_util import visualize_axial_slice

visualize_axial_slice("../data/sri24/spgr_unstrip.nii", 0.5)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 2. MONAI pipeline
#
# - Reorientation to LPS
# - Resampling to T1w
# - Isotropic Resampling
# - Foreground Cropping

# %%
# %load_ext autoreload
# %autoreload 2

from vis_util import visualize_structural_mri_session

visualize_structural_mri_session("../data/oasis-3-cluster-monai/OAS30001_MR_d0129/", slice_fraction=0.65)
visualize_structural_mri_session("../data/oasis-3-cluster-monai/OAS30001_MR_d0757/", slice_fraction=0.65)
visualize_structural_mri_session("../data/oasis-3-cluster-monai/OAS30001_MR_d2430/", slice_fraction=0.65)
visualize_structural_mri_session("../data/oasis-3-cluster-monai/OAS30002_MR_d0371/", slice_fraction=0.65)
visualize_structural_mri_session("../data/oasis-3-cluster-monai/OAS30184_MR_d0876/", slice_fraction=0.65)
visualize_structural_mri_session("../data/oasis-3-cluster-monai/OAS30250_MR_d1233/", slice_fraction=0.65)
visualize_structural_mri_session("../data/oasis-3-cluster-monai/OAS30636_MR_d2289/", slice_fraction=0.65)
visualize_structural_mri_session("../data/oasis-3-cluster-monai/OAS31372_MR_d1245/", slice_fraction=0.65)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
