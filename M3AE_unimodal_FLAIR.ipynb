# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install monai
# !pip install torchmetrics==0.7.2
# !pip install transformers
# !pip install einops
# !pip install timm==0.4.12
# Out:
# Collecting monai
#   Downloading monai-1.2.0-202306081546-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.10/dist-packages (from monai) (2.0.1+cu118)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from monai) (1.23.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.9->monai) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.9->monai) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9->monai) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9->monai) (1.3.0)
# Installing collected packages: monai
# Successfully installed monai-1.2.0
# Collecting torchmetrics==0.7.2
#   Downloading torchmetrics-0.7.2-py3-none-any.whl (397 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.2/397.2 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from torchmetrics==0.7.2) (1.23.5)
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics==0.7.2) (2.0.1+cu118)
# Collecting pyDeprecate==0.3.* (from torchmetrics==0.7.2)
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from torchmetrics==0.7.2) (23.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.1->torchmetrics==0.7.2) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.1->torchmetrics==0.7.2) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.1->torchmetrics==0.7.2) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.1->torchmetrics==0.7.2) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.1->torchmetrics==0.7.2) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.1->torchmetrics==0.7.2) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.3.1->torchmetrics==0.7.2) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.3.1->torchmetrics==0.7.2) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3.1->torchmetrics==0.7.2) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3.1->torchmetrics==0.7.2) (1.3.0)
# Installing collected packages: pyDeprecate, torchmetrics
# Successfully installed pyDeprecate-0.3.2 torchmetrics-0.7.2
# Collecting transformers
#   Downloading transformers-4.33.2-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 52.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.15.1 (from transformers)
#   Downloading huggingface_hub-0.17.1-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 33.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 81.7 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 72.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.17.1 safetensors-0.3.3 tokenizers-0.13.3 transformers-4.33.2
# Collecting einops
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.6.1
# Collecting timm==0.4.12
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.10/dist-packages (from timm==0.4.12) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm==0.4.12) (0.15.2+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4->timm==0.4.12) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4->timm==0.4.12) (16.0.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==0.4.12) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==0.4.12) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==0.4.12) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4->timm==0.4.12) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->timm==0.4.12) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->timm==0.4.12) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->timm==0.4.12) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->timm==0.4.12) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4->timm==0.4.12) (1.3.0)
# Installing collected packages: timm
# Successfully installed timm-0.4.12

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import random
import py
from sklearn.metrics import classification_report
from monai.data import decollate_batch, DataLoader, CacheDataset, ThreadDataLoader
from monai.metrics import ROCAUCMetric
from monai.transforms import (
    Activations,
    EnsureChannelFirstd,
    Compose,
    LoadImaged,
    ScaleIntensityd,
    EnsureTyped,
    Resized,
    CropForegroundd,
    SpatialPadd,
    CastToTyped,
)
from monai.utils import set_determinism

# %%
import sys
import os
import requests

import torch
import numpy as np

import matplotlib.pyplot as plt
from PIL import Image

# check whether run in Colab
if 'google.colab' in sys.modules:
    print('Running in Colab.')
    # !pip3 install timm==0.4.5  # 0.3.2 does not work in Colab
    # !git clone https://github.com/facebookresearch/mae.git
    sys.path.append('./mae')
else:
    sys.path.append('..')
import models_mae
# Out:
# Running in Colab.
# Collecting timm==0.4.5
#   Downloading timm-0.4.5-py3-none-any.whl (287 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.4/287.4 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.10/dist-packages (from timm==0.4.5) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm==0.4.5) (0.15.2+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.5) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.5) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.5) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.5) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.5) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.5) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4->timm==0.4.5) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4->timm==0.4.5) (16.0.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==0.4.5) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==0.4.5) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==0.4.5) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4->timm==0.4.5) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->timm==0.4.5) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->timm==0.4.5) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->timm==0.4.5) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->timm==0.4.5) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4->timm==0.4.5) (1.3.0)
# Installing collected packages: timm
#   Attempting uninstall: timm
#     Found existing installation: timm 0.4.12
#     Uninstalling timm-0.4.12:
#       Successfully uninstalled timm-0.4.12
# Successfully installed timm-0.4.5
# Cloning into 'mae'...
# remote: Enumerating objects: 39, done.
# remote: Total 39 (delta 0), reused 0 (delta 0), pack-reused 39
# Receiving objects: 100% (39/39), 829.54 KiB | 3.33 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
imagenet_mean = np.array([0.485, 0.456, 0.406])
imagenet_std = np.array([0.229, 0.224, 0.225])

def show_image(image, title=''):
    # image is [H, W, 3]
    assert image.shape[2] == 3
    plt.imshow(torch.clip((image * imagenet_std + imagenet_mean) * 255, 0, 255).int())
    plt.title(title, fontsize=16)
    plt.axis('off')
    return

def prepare_model(chkpt_dir, arch='mae_vit_large_patch16'):
    # build model
    model = getattr(models_mae, arch)()
    # load model
    checkpoint = torch.load(chkpt_dir, map_location='cpu')
    msg = model.load_state_dict(checkpoint['model'], strict=False)
    print(msg)
    return model

def run_one_image(img, model):
    x = torch.tensor(img)

    # make it a batch-like
    x = x.unsqueeze(dim=0)
    x = torch.einsum('nhwc->nchw', x)

    # run MAE
    loss, y, mask = model(x.float(), mask_ratio=0.75)
    y = model.unpatchify(y)
    y = torch.einsum('nchw->nhwc', y).detach().cpu()

    # visualize the mask
    mask = mask.detach()
    mask = mask.unsqueeze(-1).repeat(1, 1, model.patch_embed.patch_size[0]**2 *3)  # (N, H*W, p*p*3)
    mask = model.unpatchify(mask)  # 1 is removing, 0 is keeping
    mask = torch.einsum('nchw->nhwc', mask).detach().cpu()

    x = torch.einsum('nchw->nhwc', x)

    # masked image
    im_masked = x * (1 - mask)

    # MAE reconstruction pasted with visible patches
    im_paste = x * (1 - mask) + y * mask

    # make the plt figure larger
    plt.rcParams['figure.figsize'] = [24, 24]

    plt.subplot(1, 4, 1)
    show_image(x[0], "original")

    plt.subplot(1, 4, 2)
    show_image(im_masked[0], "masked")

    plt.subplot(1, 4, 3)
    show_image(y[0], "reconstruction")

    plt.subplot(1, 4, 4)
    show_image(im_paste[0], "reconstruction + visible")

    plt.show()

# %%
def set_seed(no):
    torch.manual_seed(no)
    random.seed(no)
    np.random.seed(no)
    os.environ['PYTHONHASHSEED'] = str()
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

set_seed(100)

# %%
import pandas as pd
import os
from enum import Enum
from monai.transforms import Transform

class Modality(Enum):
    MR_T1 = 1
    MR_T2 = 2
    MR_T2_STAR = 3
    MR_FLAIR = 4
    MR_TOF_MRA = 5

def create_oasis_3_unimodal_dataset(csv_path: str, dataset_root: str, modality: Modality, transform: Transform, cache_rate: float):
    train_df = pd.read_csv(csv_path, sep=";")
    train_df.fillna('', inplace=True)

    column_name = ""
    if modality == Modality.MR_T1:
        column_name = "MR T1w"
    elif modality == Modality.MR_T2:
        column_name = "MR T2w"
    elif modality == Modality.MR_T2_STAR:
        column_name = "MR T2*"
    elif modality == Modality.MR_FLAIR:
        column_name = "MR FLAIR"
    elif modality == Modality.MR_TOF_MRA:
        column_name = "MR TOF-MRA"
    else:
        assert(False)

    train_data = []
    for index, row in train_df.iterrows():
        rel_path = row[column_name]
        if not rel_path:
            continue
        image_path = os.path.join(dataset_root, rel_path)
        if "sub-OAS31065_ses-d0044_echo-1_run-02_FLAIR.nii.gz" in image_path:
          continue
        print(image_path)
        train_data.append({"image": image_path, "label" : row["label"]})

    return CacheDataset(data=train_data, transform=transform, cache_rate=cache_rate, num_workers=5, copy_cache=False)

# %%
dataset_root = r"/content/drive/MyDrive/OASIS-3-MR-Sessions-2D"

# %%
resolution = 224
cache_rate = 0.1 # might need to change this based on the amount of memory available
batch_size = 16
modality = Modality.MR_FLAIR

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
foreground_crop_threshold = 0.1
# train_table_path = "csv/oasis/oasis_3_multimodal_train.csv"
train_table_path = r"/content/drive/MyDrive/MLMI/oasis_3_multimodal_train.csv"
transform = Compose([
    LoadImaged("image", image_only=True),
    EnsureChannelFirstd(keys=["image", "label"], channel_dim="no_channel"),
    CastToTyped("label", dtype=np.float64),
    ScaleIntensityd("image"),
    CropForegroundd("image", source_key="image", select_fn=lambda x: x > foreground_crop_threshold, margin=5),
    Resized(keys=["image"], spatial_size=resolution, size_mode="longest"),
    SpatialPadd(keys=["image"], spatial_size=(resolution, resolution)),
    EnsureTyped("image", device=device),
    ]
)

# TODO: fix the following files
# TODO: skip them in the dataset
'''
torch.Size([96, 96, 26])
Error transforming file: /mnt/f/OASIS-3-MR-Sessions-2D/OAS30033_MR_d0133/anat5/NIFTI/sub-OAS30033_ses-d0133_run-02_T2w.nii.gz

torch.Size([64, 64, 105])
Error transforming file: /mnt/f/OASIS-3-MR-Sessions-2D/OAS31065_MR_d0044/anat7/NIFTI/sub-OAS31065_ses-d0044_echo-1_run-02_FLAIR.nii.gz
'''

train_ds = create_oasis_3_unimodal_dataset(csv_path=train_table_path, dataset_root=dataset_root, modality=modality, transform=transform, cache_rate=cache_rate)
train_loader = ThreadDataLoader(train_ds, num_workers=0, batch_size=batch_size, shuffle=True)

# val_table_path = "csv/oasis/oasis_3_multimodal_val.csv"
val_table_path = r"/content/drive/MyDrive/MLMI/oasis_3_multimodal_val.csv"
val_ds = create_oasis_3_unimodal_dataset(csv_path=val_table_path, dataset_root=dataset_root, modality=modality, transform=transform, cache_rate=cache_rate)
val_loader = ThreadDataLoader(val_ds, num_workers=0, batch_size=batch_size, shuffle=True)
# Out:
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31022_MR_d0089/anat1/NIFTI/sub-OAS31022_ses-d0089_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31114_MR_d2658/anat3/NIFTI/sub-OAS31114_ses-d2658_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31232_MR_d0159/anat1/NIFTI/sub-OAS31232_sess-d0159_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30055_MR_d0566/anat2/NIFTI/sub-OAS30055_sess-d0566_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30535_MR_d1336/anat3/NIFTI/sub-OAS30535_ses-d1336_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30956_MR_d2573/anat2/NIFTI/sub-OAS30956_ses-d2573_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30371_MR_d1400/anat3/NIFTI/sub-OAS30371_ses-d1400_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30876_MR_d2447/anat2/NIFTI/sub-OAS30876_ses-d2447_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31015_MR_d0222/anat1/NIFTI/sub-OAS31015_ses-d0222_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31147_MR_d1218/anat3/NIFTI/sub-OAS31147_sess-d1218_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30637_MR_d0079/anat3/NIFTI/sub-OAS30637_ses-d0079_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30114_MR_d0086/anat3/NIFTI/sub-OAS30114_ses-d0086_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30559_MR_d0431/anat2/NIFTI/sub-OAS30559_ses-d0431_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30632_MR_d3040/anat1/NIFTI/sub-OAS30632_sess-d3040_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30823_MR_d2722/anat3/NIFTI/sub-OAS30823_ses-d2722_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31340_MR_d0143/anat3/NIFTI/sub-OAS31340_sess-d0143_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30606_MR_d2822/anat1/NIFTI/sub-OAS30606_sess-d2822_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30049_MR_d2933/anat3/NIFTI/sub-OAS30049_sess-d2933_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31407_MR_d0098/anat3/NIFTI/sub-OAS31407_sess-d0098_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30073_MR_d2851/anat2/NIFTI/sub-OAS30073_ses-d2851_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31179_MR_d0180/anat3/NIFTI/sub-OAS31179_sess-d0180_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30367_MR_d5611/anat1/NIFTI/sub-OAS30367_sess-d5611_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30044_MR_d1319/anat3/NIFTI/sub-OAS30044_ses-d1319_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30417_MR_d0107/anat1/NIFTI/sub-OAS30417_ses-d0107_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30423_MR_d2099/anat3/NIFTI/sub-OAS30423_ses-d2099_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30845_MR_d1266/anat3/NIFTI/sub-OAS30845_ses-d1266_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31472_MR_d0045/anat1/NIFTI/sub-OAS31472_sess-d0045_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30852_MR_d6963/anat1/NIFTI/sub-OAS30852_ses-d6963_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30178_MR_d1384/anat2/NIFTI/sub-OAS30178_ses-d1384_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31285_MR_d0055/anat3/NIFTI/sub-OAS31285_sess-d0055_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30720_MR_d4213/anat1/NIFTI/sub-OAS30720_ses-d4213_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30813_MR_d0138/anat1/NIFTI/sub-OAS30813_ses-d0138_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30448_MR_d0101/anat1/NIFTI/sub-OAS30448_ses-d0101_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30369_MR_d5872/anat2/NIFTI/sub-OAS30369_ses-d5872_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30469_MR_d0112/anat1/NIFTI/sub-OAS30469_ses-d0112_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31279_MR_d0020/anat1/NIFTI/sub-OAS31279_sess-d0020_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30361_MR_d3275/anat3/NIFTI/sub-OAS30361_ses-d3275_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30372_MR_d4514/anat2/NIFTI/sub-OAS30372_ses-d4514_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30083_MR_d3827/anat3/NIFTI/sub-OAS30083_ses-d3827_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31360_MR_d0158/anat1/NIFTI/sub-OAS31360_sess-d0158_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30281_MR_d0042/anat3/NIFTI/sub-OAS30281_ses-d0042_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30182_MR_d2289/anat1/NIFTI/sub-OAS30182_sess-d2289_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31167_MR_d2053/anat2/NIFTI/sub-OAS31167_ses-d2053_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30219_MR_d0064/anat2/NIFTI/sub-OAS30219_ses-d0064_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30846_MR_d1101/anat1/NIFTI/sub-OAS30846_sess-d1101_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30135_MR_d2367/anat3/NIFTI/sub-OAS30135_ses-d2367_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30435_MR_d0054/anat2/NIFTI/sub-OAS30435_sess-d0054_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30995_MR_d0054/anat2/NIFTI/sub-OAS30995_ses-d0054_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30723_MR_d1179/anat2/NIFTI/sub-OAS30723_ses-d1179_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31053_MR_d0057/anat2/NIFTI/sub-OAS31053_sess-d0057_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30048_MR_d3375/anat3/NIFTI/sub-OAS30048_ses-d3375_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31304_MR_d0084/anat1/NIFTI/sub-OAS31304_sess-d0084_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30993_MR_d0920/anat1/NIFTI/sub-OAS30993_ses-d0920_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31313_MR_d0047/anat3/NIFTI/sub-OAS31313_sess-d0047_run-02_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30807_MR_d1492/anat1/NIFTI/sub-OAS30807_sess-d1492_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30699_MR_d5530/anat1/NIFTI/sub-OAS30699_sess-d5530_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31321_MR_d0044/anat1/NIFTI/sub-OAS31321_sess-d0044_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30322_MR_d3851/anat3/NIFTI/sub-OAS30322_ses-d3851_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30073_MR_d4456/anat3/NIFTI/sub-OAS30073_ses-d4456_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31068_MR_d3484/anat3/NIFTI/sub-OAS31068_ses-d3484_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30587_MR_d4511/anat3/NIFTI/sub-OAS30587_ses-d4511_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30297_MR_d2331/anat2/NIFTI/sub-OAS30297_sess-d2331_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31081_MR_d5241/anat1/NIFTI/sub-OAS31081_sess-d5241_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30341_MR_d0025/anat1/NIFTI/sub-OAS30341_ses-d0025_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31303_MR_d0015/anat5/NIFTI/sub-OAS31303_sess-d0015_run-02_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31395_MR_d0044/anat3/NIFTI/sub-OAS31395_sess-d0044_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31256_MR_d0163/anat1/NIFTI/sub-OAS31256_sess-d0163_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31197_MR_d0179/anat1/NIFTI/sub-OAS31197_sess-d0179_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30007_MR_d3807/anat1/NIFTI/sub-OAS30007_sess-d3807_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31020_MR_d1475/anat3/NIFTI/sub-OAS31020_sess-d1475_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31150_MR_d1416/anat3/NIFTI/sub-OAS31150_ses-d1416_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30561_MR_d1137/anat3/NIFTI/sub-OAS30561_sess-d1137_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30597_MR_d3137/anat3/NIFTI/sub-OAS30597_ses-d3137_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30005_MR_d2384/anat3/NIFTI/sub-OAS30005_ses-d2384_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31320_MR_d0036/anat1/NIFTI/sub-OAS31320_sess-d0036_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30484_MR_d0557/anat3/NIFTI/sub-OAS30484_ses-d0557_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31090_MR_d3565/anat1/NIFTI/sub-OAS31090_ses-d3565_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30028_MR_d1260/anat3/NIFTI/sub-OAS30028_ses-d1260_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30137_MR_d3165/anat2/NIFTI/sub-OAS30137_ses-d3165_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30537_MR_d2813/anat3/NIFTI/sub-OAS30537_sess-d2813_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30959_MR_d2692/anat3/NIFTI/sub-OAS30959_ses-d2692_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30699_MR_d1809/anat2/NIFTI/sub-OAS30699_ses-d1809_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31343_MR_d0902/anat1/NIFTI/sub-OAS31343_sess-d0902_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31078_MR_d1173/anat2/NIFTI/sub-OAS31078_ses-d1173_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31370_MR_d0097/anat1/NIFTI/sub-OAS31370_sess-d0097_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30579_MR_d3440/anat5/NIFTI/sub-OAS30579_sess-d3440_run-02_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30178_MR_d2455/anat3/NIFTI/sub-OAS30178_ses-d2455_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31455_MR_d0087/anat1/NIFTI/sub-OAS31455_sess-d0087_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30455_MR_d2887/anat3/NIFTI/sub-OAS30455_ses-d2887_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30252_MR_d0119/anat3/NIFTI/sub-OAS30252_sess-d0119_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30538_MR_d0105/anat1/NIFTI/sub-OAS30538_ses-d0105_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30328_MR_d0470/anat3/NIFTI/sub-OAS30328_ses-d0470_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30832_MR_d4580/anat1/NIFTI/sub-OAS30832_sess-d4580_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31440_MR_d0040/anat1/NIFTI/sub-OAS31440_sess-d0040_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30250_MR_d1722/anat3/NIFTI/sub-OAS30250_ses-d1722_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31379_MR_d0071/anat3/NIFTI/sub-OAS31379_sess-d0071_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31300_MR_d0212/anat3/NIFTI/sub-OAS31300_sess-d0212_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31401_MR_d0120/anat1/NIFTI/sub-OAS31401_sess-d0120_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30079_MR_d3410/anat3/NIFTI/sub-OAS30079_sess-d3410_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30342_MR_d0429/anat3/NIFTI/sub-OAS30342_ses-d0429_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30004_MR_d2232/anat2/NIFTI/sub-OAS30004_ses-d2232_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30725_MR_d2456/anat3/NIFTI/sub-OAS30725_ses-d2456_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30276_MR_d2405/anat3/NIFTI/sub-OAS30276_ses-d2405_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30263_MR_d4709/anat1/NIFTI/sub-OAS30263_sess-d4709_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30887_MR_d1407/anat3/NIFTI/sub-OAS30887_ses-d1407_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30706_MR_d0060/anat1/NIFTI/sub-OAS30706_ses-d0060_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30664_MR_d3557/anat1/NIFTI/sub-OAS30664_ses-d3557_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30241_MR_d4514/anat3/NIFTI/sub-OAS30241_sess-d4514_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31380_MR_d0132/anat3/NIFTI/sub-OAS31380_sess-d0132_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30561_MR_d1263/anat1/NIFTI/sub-OAS30561_sess-d1263_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30647_MR_d1286/anat3/NIFTI/sub-OAS30647_ses-d1286_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31028_MR_d2386/anat1/NIFTI/sub-OAS31028_sess-d2386_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30240_MR_d5621/anat1/NIFTI/sub-OAS30240_sess-d5621_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30742_MR_d4551/anat3/NIFTI/sub-OAS30742_ses-d4551_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30683_MR_d2368/anat5/NIFTI/sub-OAS30683_sess-d2368_run-02_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31437_MR_d0140/anat1/NIFTI/sub-OAS31437_sess-d0140_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30160_MR_d2392/anat2/NIFTI/sub-OAS30160_ses-d2392_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30455_MR_d4209/anat1/NIFTI/sub-OAS30455_ses-d4209_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30333_MR_d4277/anat1/NIFTI/sub-OAS30333_sess-d4277_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30371_MR_d0981/anat3/NIFTI/sub-OAS30371_ses-d0981_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30346_MR_d1685/anat3/NIFTI/sub-OAS30346_ses-d1685_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30137_MR_d5772/anat1/NIFTI/sub-OAS30137_sess-d5772_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30635_MR_d1533/anat3/NIFTI/sub-OAS30635_sess-d1533_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30291_MR_d3148/anat3/NIFTI/sub-OAS30291_sess-d3148_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30349_MR_d3241/anat1/NIFTI/sub-OAS30349_ses-d3241_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31261_MR_d0095/anat1/NIFTI/sub-OAS31261_sess-d0095_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30756_MR_d0022/anat3/NIFTI/sub-OAS30756_ses-d0022_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30798_MR_d1003/anat1/NIFTI/sub-OAS30798_sess-d1003_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30818_MR_d3524/anat1/NIFTI/sub-OAS30818_sess-d3524_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31310_MR_d0082/anat1/NIFTI/sub-OAS31310_sess-d0082_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30204_MR_d0033/anat3/NIFTI/sub-OAS30204_ses-d0033_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30743_MR_d2309/anat2/NIFTI/sub-OAS30743_ses-d2309_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31137_MR_d5544/anat1/NIFTI/sub-OAS31137_sess-d5544_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31219_MR_d0098/anat1/NIFTI/sub-OAS31219_sess-d0098_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30515_MR_d0044/anat3/NIFTI/sub-OAS30515_ses-d0044_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31418_MR_d0068/anat5/NIFTI/sub-OAS31418_sess-d0068_run-02_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30713_MR_d4047/anat2/NIFTI/sub-OAS30713_sess-d4047_run-02_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30048_MR_d3731/anat3/NIFTI/sub-OAS30048_ses-d3731_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31420_MR_d0025/anat1/NIFTI/sub-OAS31420_sess-d0025_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31118_MR_d3618/anat4/NIFTI/sub-OAS31118_sess-d3618_run-02_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31348_MR_d0100/anat1/NIFTI/sub-OAS31348_sess-d0100_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30558_MR_d4493/anat1/NIFTI/sub-OAS30558_ses-d4493_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31059_MR_d3491/anat3/NIFTI/sub-OAS31059_ses-d3491_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30819_MR_d1776/anat3/NIFTI/sub-OAS30819_sess-d1776_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30353_MR_d2635/anat2/NIFTI/sub-OAS30353_ses-d2635_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30803_MR_d5619/anat1/NIFTI/sub-OAS30803_sess-d5619_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30823_MR_d1309/anat2/NIFTI/sub-OAS30823_ses-d1309_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30599_MR_d0121/anat1/NIFTI/sub-OAS30599_ses-d0121_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31203_MR_d0237/anat1/NIFTI/sub-OAS31203_sess-d0237_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30823_MR_d3459/anat3/NIFTI/sub-OAS30823_sess-d3459_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31220_MR_d0082/anat3/NIFTI/sub-OAS31220_sess-d0082_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30996_MR_d4705/anat3/NIFTI/sub-OAS30996_ses-d4705_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30026_MR_d0696/anat3/NIFTI/sub-OAS30026_ses-d0696_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30321_MR_d3003/anat1/NIFTI/sub-OAS30321_sess-d3003_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30519_MR_d0080/anat1/NIFTI/sub-OAS30519_ses-d0080_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31065_MR_d0056/anat2/NIFTI/sub-OAS31065_ses-d0056_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30713_MR_d2308/anat2/NIFTI/sub-OAS30713_ses-d2308_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31048_MR_d2385/anat1/NIFTI/sub-OAS31048_ses-d2385_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30558_MR_d2148/anat2/NIFTI/sub-OAS30558_ses-d2148_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31257_MR_d0097/anat1/NIFTI/sub-OAS31257_sess-d0097_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30191_MR_d1136/anat2/NIFTI/sub-OAS30191_ses-d1136_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30986_MR_d2308/anat2/NIFTI/sub-OAS30986_ses-d2308_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30607_MR_d0117/anat1/NIFTI/sub-OAS30607_ses-d0117_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30713_MR_d1692/anat2/NIFTI/sub-OAS30713_ses-d1692_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31039_MR_d0001/anat2/NIFTI/sub-OAS31039_ses-d0001_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31302_MR_d0056/anat2/NIFTI/sub-OAS31302_sess-d0056_run-02_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30809_MR_d0252/anat3/NIFTI/sub-OAS30809_ses-d0252_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31430_MR_d0060/anat1/NIFTI/sub-OAS31430_sess-d0060_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31319_MR_d0075/anat1/NIFTI/sub-OAS31319_sess-d0075_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30487_MR_d1338/anat2/NIFTI/sub-OAS30487_ses-d1338_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31084_MR_d3445/anat1/NIFTI/sub-OAS31084_sess-d3445_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30807_MR_d0472/anat3/NIFTI/sub-OAS30807_ses-d0472_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31073_MR_d3760/anat3/NIFTI/sub-OAS31073_sess-d3760_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31471_MR_d0059/anat1/NIFTI/sub-OAS31471_sess-d0059_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30065_MR_d2009/anat3/NIFTI/sub-OAS30065_ses-d2009_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31189_MR_d0112/anat3/NIFTI/sub-OAS31189_sess-d0112_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30531_MR_d0108/anat2/NIFTI/sub-OAS30531_ses-d0108_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30288_MR_d4509/anat3/NIFTI/sub-OAS30288_ses-d4509_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31167_MR_d4564/anat3/NIFTI/sub-OAS31167_ses-d4564_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31381_MR_d0032/anat1/NIFTI/sub-OAS31381_sess-d0032_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31083_MR_d1232/anat2/NIFTI/sub-OAS31083_ses-d1232_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30486_MR_d0075/anat2/NIFTI/sub-OAS30486_sess-d0075_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30242_MR_d0137/anat3/NIFTI/sub-OAS30242_ses-d0137_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30464_MR_d2848/anat3/NIFTI/sub-OAS30464_ses-d2848_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30242_MR_d1138/anat3/NIFTI/sub-OAS30242_sess-d1138_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30127_MR_d0837/anat3/NIFTI/sub-OAS30127_ses-d0837_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30201_MR_d0077/anat3/NIFTI/sub-OAS30201_sess-d0077_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30568_MR_d0073/anat2/NIFTI/sub-OAS30568_ses-d0073_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30044_MR_d0061/anat3/NIFTI/sub-OAS30044_ses-d0061_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30455_MR_d2888/anat1/NIFTI/sub-OAS30455_ses-d2888_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30527_MR_d0000/anat1/NIFTI/sub-OAS30527_sess-d0000_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30293_MR_d0056/anat2/NIFTI/sub-OAS30293_ses-d0056_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31192_MR_d0036/anat1/NIFTI/sub-OAS31192_sess-d0036_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30083_MR_d2882/anat3/NIFTI/sub-OAS30083_ses-d2882_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31233_MR_d0246/anat1/NIFTI/sub-OAS31233_sess-d0246_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30523_MR_d0027/anat2/NIFTI/sub-OAS30523_ses-d0027_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31297_MR_d0035/anat1/NIFTI/sub-OAS31297_sess-d0035_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30708_MR_d0071/anat3/NIFTI/sub-OAS30708_ses-d0071_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31056_MR_d1912/anat3/NIFTI/sub-OAS31056_ses-d1912_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31222_MR_d0040/anat1/NIFTI/sub-OAS31222_sess-d0040_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31099_MR_d4993/anat1/NIFTI/sub-OAS31099_sess-d4993_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30447_MR_d0120/anat3/NIFTI/sub-OAS30447_sess-d0120_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30003_MR_d4954/anat1/NIFTI/sub-OAS30003_sess-d4954_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30108_MR_d2066/anat3/NIFTI/sub-OAS30108_ses-d2066_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31444_MR_d0321/anat1/NIFTI/sub-OAS31444_sess-d0321_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30986_MR_d4711/anat3/NIFTI/sub-OAS30986_sess-d4711_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30413_MR_d1533/anat2/NIFTI/sub-OAS30413_ses-d1533_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30101_MR_d2650/anat1/NIFTI/sub-OAS30101_ses-d2650_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31195_MR_d0098/anat3/NIFTI/sub-OAS31195_sess-d0098_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30852_MR_d7830/anat1/NIFTI/sub-OAS30852_sess-d7830_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31429_MR_d0062/anat1/NIFTI/sub-OAS31429_sess-d0062_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30715_MR_d2444/anat1/NIFTI/sub-OAS30715_sess-d2444_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30062_MR_d4447/anat2/NIFTI/sub-OAS30062_sess-d4447_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31327_MR_d0062/anat1/NIFTI/sub-OAS31327_sess-d0062_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31127_MR_d2140/anat3/NIFTI/sub-OAS31127_ses-d2140_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30769_MR_d1554/anat3/NIFTI/sub-OAS30769_ses-d1554_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31000_MR_d0072/anat3/NIFTI/sub-OAS31000_ses-d0072_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30869_MR_d1691/anat2/NIFTI/sub-OAS30869_ses-d1691_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30256_MR_d2368/anat2/NIFTI/sub-OAS30256_ses-d2368_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30659_MR_d1668/anat3/NIFTI/sub-OAS30659_ses-d1668_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30854_MR_d1385/anat2/NIFTI/sub-OAS30854_ses-d1385_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31389_MR_d0140/anat3/NIFTI/sub-OAS31389_sess-d0140_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31221_MR_d0017/anat1/NIFTI/sub-OAS31221_sess-d0017_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30113_MR_d2280/anat2/NIFTI/sub-OAS30113_ses-d2280_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31237_MR_d0172/anat3/NIFTI/sub-OAS31237_sess-d0172_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31428_MR_d0022/anat1/NIFTI/sub-OAS31428_sess-d0022_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31448_MR_d0137/anat1/NIFTI/sub-OAS31448_sess-d0137_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30107_MR_d2765/anat2/NIFTI/sub-OAS30107_ses-d2765_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30695_MR_d0104/anat3/NIFTI/sub-OAS30695_ses-d0104_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30757_MR_d2279/anat2/NIFTI/sub-OAS30757_ses-d2279_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30034_MR_d0044/anat2/NIFTI/sub-OAS30034_ses-d0044_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31161_MR_d0056/anat1/NIFTI/sub-OAS31161_ses-d0056_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31345_MR_d0034/anat1/NIFTI/sub-OAS31345_sess-d0034_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31397_MR_d0058/anat1/NIFTI/sub-OAS31397_sess-d0058_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31249_MR_d0063/anat1/NIFTI/sub-OAS31249_sess-d0063_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30531_MR_d2584/anat3/NIFTI/sub-OAS30531_ses-d2584_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31138_MR_d2040/anat3/NIFTI/sub-OAS31138_ses-d2040_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31218_MR_d0067/anat1/NIFTI/sub-OAS31218_sess-d0067_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30701_MR_d2371/anat3/NIFTI/sub-OAS30701_ses-d2371_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31333_MR_d0056/anat1/NIFTI/sub-OAS31333_sess-d0056_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30432_MR_d2137/anat1/NIFTI/sub-OAS30432_sess-d2137_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30756_MR_d0014/anat2/NIFTI/sub-OAS30756_ses-d0014_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30387_MR_d3401/anat3/NIFTI/sub-OAS30387_ses-d3401_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31072_MR_d5711/anat1/NIFTI/sub-OAS31072_sess-d5711_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31413_MR_d0144/anat1/NIFTI/sub-OAS31413_sess-d0144_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31404_MR_d0010/anat1/NIFTI/sub-OAS31404_sess-d0010_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31071_MR_d0068/anat3/NIFTI/sub-OAS31071_ses-d0068_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31018_MR_d1606/anat1/NIFTI/sub-OAS31018_sess-d1606_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30066_MR_d2006/anat3/NIFTI/sub-OAS30066_ses-d2006_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30337_MR_d0064/anat3/NIFTI/sub-OAS30337_ses-d0064_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31265_MR_d0028/anat1/NIFTI/sub-OAS31265_sess-d0028_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30579_MR_d1232/anat2/NIFTI/sub-OAS30579_ses-d1232_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30731_MR_d3375/anat1/NIFTI/sub-OAS30731_sess-d3375_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31338_MR_d0120/anat1/NIFTI/sub-OAS31338_sess-d0120_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30921_MR_d2464/anat3/NIFTI/sub-OAS30921_ses-d2464_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30417_MR_d2265/anat1/NIFTI/sub-OAS30417_sess-d2265_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30476_MR_d0482/anat3/NIFTI/sub-OAS30476_ses-d0482_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31034_MR_d0203/anat2/NIFTI/sub-OAS31034_ses-d0203_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30858_MR_d4129/anat1/NIFTI/sub-OAS30858_sess-d4129_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30128_MR_d0044/anat3/NIFTI/sub-OAS30128_ses-d0044_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30507_MR_d3571/anat3/NIFTI/sub-OAS30507_sess-d3571_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31080_MR_d0183/anat1/NIFTI/sub-OAS31080_ses-d0183_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30869_MR_d2290/anat2/NIFTI/sub-OAS30869_ses-d2290_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31299_MR_d0061/anat1/NIFTI/sub-OAS31299_sess-d0061_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30499_MR_d2296/anat3/NIFTI/sub-OAS30499_ses-d2296_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31064_MR_d2091/anat2/NIFTI/sub-OAS31064_ses-d2091_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30048_MR_d2292/anat2/NIFTI/sub-OAS30048_ses-d2292_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30956_MR_d1314/anat2/NIFTI/sub-OAS30956_ses-d1314_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30861_MR_d1702/anat3/NIFTI/sub-OAS30861_ses-d1702_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31070_MR_d0084/anat3/NIFTI/sub-OAS31070_ses-d0084_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31150_MR_d2604/anat1/NIFTI/sub-OAS31150_sess-d2604_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30057_MR_d0075/anat3/NIFTI/sub-OAS30057_ses-d0075_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31149_MR_d1386/anat1/NIFTI/sub-OAS31149_sess-d1386_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31460_MR_d0053/anat3/NIFTI/sub-OAS31460_sess-d0053_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31470_MR_d0007/anat1/NIFTI/sub-OAS31470_sess-d0007_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30922_MR_d1406/anat1/NIFTI/sub-OAS30922_sess-d1406_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31391_MR_d0112/anat1/NIFTI/sub-OAS31391_sess-d0112_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30755_MR_d3410/anat1/NIFTI/sub-OAS30755_sess-d3410_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30204_MR_d0020/anat2/NIFTI/sub-OAS30204_ses-d0020_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31205_MR_d0077/anat3/NIFTI/sub-OAS31205_sess-d0077_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31224_MR_d0116/anat3/NIFTI/sub-OAS31224_sess-d0116_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31369_MR_d0074/anat3/NIFTI/sub-OAS31369_sess-d0074_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30002_MR_d2340/anat3/NIFTI/sub-OAS30002_ses-d2340_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31076_MR_d1261/anat1/NIFTI/sub-OAS31076_sess-d1261_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30934_MR_d2150/anat3/NIFTI/sub-OAS30934_ses-d2150_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30090_MR_d2676/anat1/NIFTI/sub-OAS30090_sess-d2676_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30434_MR_d0054/anat3/NIFTI/sub-OAS30434_ses-d0054_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30872_MR_d3097/anat1/NIFTI/sub-OAS30872_ses-d3097_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30580_MR_d1531/anat3/NIFTI/sub-OAS30580_ses-d1531_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30105_MR_d1228/anat1/NIFTI/sub-OAS30105_sess-d1228_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30414_MR_d2163/anat1/NIFTI/sub-OAS30414_sess-d2163_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30353_MR_d3421/anat2/NIFTI/sub-OAS30353_ses-d3421_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30775_MR_d2395/anat3/NIFTI/sub-OAS30775_ses-d2395_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31137_MR_d4519/anat1/NIFTI/sub-OAS31137_sess-d4519_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31011_MR_d0089/anat3/NIFTI/sub-OAS31011_ses-d0089_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30959_MR_d4631/anat3/NIFTI/sub-OAS30959_sess-d4631_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31094_MR_d3350/anat1/NIFTI/sub-OAS31094_sess-d3350_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31290_MR_d0048/anat1/NIFTI/sub-OAS31290_sess-d0048_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31286_MR_d0058/anat1/NIFTI/sub-OAS31286_sess-d0058_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30499_MR_d3468/anat1/NIFTI/sub-OAS30499_sess-d3468_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30199_MR_d0024/anat2/NIFTI/sub-OAS30199_ses-d0024_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30612_MR_d2356/anat1/NIFTI/sub-OAS30612_sess-d2356_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30676_MR_d5558/anat1/NIFTI/sub-OAS30676_sess-d5558_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30988_MR_d0033/anat3/NIFTI/sub-OAS30988_ses-d0033_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30502_MR_d1195/anat3/NIFTI/sub-OAS30502_ses-d1195_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30970_MR_d0238/anat3/NIFTI/sub-OAS30970_ses-d0238_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30449_MR_d2359/anat2/NIFTI/sub-OAS30449_ses-d2359_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30503_MR_d0000/anat2/NIFTI/sub-OAS30503_ses-d0000_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30651_MR_d3150/anat3/NIFTI/sub-OAS30651_sess-d3150_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30013_MR_d1216/anat3/NIFTI/sub-OAS30013_sess-d1216_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30230_MR_d3855/anat3/NIFTI/sub-OAS30230_ses-d3855_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30445_MR_d0133/anat3/NIFTI/sub-OAS30445_ses-d0133_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30074_MR_d1871/anat2/NIFTI/sub-OAS30074_ses-d1871_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30862_MR_d3654/anat3/NIFTI/sub-OAS30862_ses-d3654_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30055_MR_d0065/anat3/NIFTI/sub-OAS30055_sess-d0065_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30817_MR_d1254/anat2/NIFTI/sub-OAS30817_ses-d1254_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30896_MR_d3528/anat3/NIFTI/sub-OAS30896_ses-d3528_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30960_MR_d5864/anat1/NIFTI/sub-OAS30960_sess-d5864_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31359_MR_d0001/anat1/NIFTI/sub-OAS31359_sess-d0001_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30978_MR_d2117/anat1/NIFTI/sub-OAS30978_sess-d2117_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31072_MR_d2178/anat2/NIFTI/sub-OAS31072_ses-d2178_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30786_MR_d3713/anat3/NIFTI/sub-OAS30786_ses-d3713_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30568_MR_d2326/anat3/NIFTI/sub-OAS30568_ses-d2326_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31018_MR_d1208/anat3/NIFTI/sub-OAS31018_ses-d1208_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31243_MR_d0116/anat1/NIFTI/sub-OAS31243_sess-d0116_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30827_MR_d1875/anat3/NIFTI/sub-OAS30827_ses-d1875_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30620_MR_d3446/anat1/NIFTI/sub-OAS30620_sess-d3446_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30304_MR_d0027/anat3/NIFTI/sub-OAS30304_ses-d0027_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30816_MR_d4576/anat3/NIFTI/sub-OAS30816_sess-d4576_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30126_MR_d3465/anat3/NIFTI/sub-OAS30126_ses-d3465_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31153_MR_d1174/anat3/NIFTI/sub-OAS31153_ses-d1174_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30989_MR_d2594/anat3/NIFTI/sub-OAS30989_ses-d2594_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30597_MR_d4209/anat2/NIFTI/sub-OAS30597_sess-d4209_run-02_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31142_MR_d4594/anat3/NIFTI/sub-OAS31142_sess-d4594_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31146_MR_d1882/anat3/NIFTI/sub-OAS31146_sess-d1882_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30128_MR_d1254/anat1/NIFTI/sub-OAS30128_sess-d1254_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30792_MR_d3410/anat3/NIFTI/sub-OAS30792_sess-d3410_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30723_MR_d2568/anat3/NIFTI/sub-OAS30723_ses-d2568_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30781_MR_d0971/anat3/NIFTI/sub-OAS30781_ses-d0971_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30048_MR_d3367/anat2/NIFTI/sub-OAS30048_ses-d3367_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30525_MR_d3407/anat3/NIFTI/sub-OAS30525_ses-d3407_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30542_MR_d3116/anat2/NIFTI/sub-OAS30542_ses-d3116_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31083_MR_d3346/anat3/NIFTI/sub-OAS31083_sess-d3346_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30099_MR_d1605/anat3/NIFTI/sub-OAS30099_sess-d1605_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30160_MR_d3534/anat1/NIFTI/sub-OAS30160_sess-d3534_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30535_MR_d2624/anat3/NIFTI/sub-OAS30535_sess-d2624_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30759_MR_d1442/anat3/NIFTI/sub-OAS30759_sess-d1442_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30633_MR_d2223/anat3/NIFTI/sub-OAS30633_ses-d2223_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31006_MR_d1106/anat1/NIFTI/sub-OAS31006_ses-d1106_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30608_MR_d3984/anat3/NIFTI/sub-OAS30608_ses-d3984_run-02_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30659_MR_d2788/anat7/NIFTI/sub-OAS30659_sess-d2788_run-02_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30485_MR_d0084/anat1/NIFTI/sub-OAS30485_ses-d0084_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30775_MR_d3017/anat3/NIFTI/sub-OAS30775_ses-d3017_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30534_MR_d3728/anat3/NIFTI/sub-OAS30534_ses-d3728_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30572_MR_d0064/anat3/NIFTI/sub-OAS30572_ses-d0064_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30167_MR_d1340/anat3/NIFTI/sub-OAS30167_ses-d1340_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30842_MR_d1298/anat3/NIFTI/sub-OAS30842_sess-d1298_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30112_MR_d1196/anat3/NIFTI/sub-OAS30112_ses-d1196_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30284_MR_d4667/anat1/NIFTI/sub-OAS30284_sess-d4667_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30208_MR_d3143/anat1/NIFTI/sub-OAS30208_sess-d3143_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30290_MR_d0000/anat3/NIFTI/sub-OAS30290_ses-d0000_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30129_MR_d1271/anat3/NIFTI/sub-OAS30129_sess-d1271_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30970_MR_d0237/anat3/NIFTI/sub-OAS30970_sess-d0237_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30146_MR_d3322/anat2/NIFTI/sub-OAS30146_ses-d3322_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31250_MR_d0174/anat5/NIFTI/sub-OAS31250_sess-d0174_run-02_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30042_MR_d1264/anat2/NIFTI/sub-OAS30042_sess-d1264_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31431_MR_d0070/anat1/NIFTI/sub-OAS31431_sess-d0070_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31020_MR_d0651/anat3/NIFTI/sub-OAS31020_ses-d0651_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30555_MR_d2548/anat3/NIFTI/sub-OAS30555_sess-d2548_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30452_MR_d6033/anat1/NIFTI/sub-OAS30452_sess-d6033_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30746_MR_d0035/anat3/NIFTI/sub-OAS30746_ses-d0035_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30246_MR_d1591/anat2/NIFTI/sub-OAS30246_ses-d1591_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30189_MR_d0072/anat1/NIFTI/sub-OAS30189_ses-d0072_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30813_MR_d1156/anat3/NIFTI/sub-OAS30813_sess-d1156_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30315_MR_d0124/anat3/NIFTI/sub-OAS30315_ses-d0124_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31278_MR_d0146/anat1/NIFTI/sub-OAS31278_sess-d0146_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30235_MR_d0139/anat2/NIFTI/sub-OAS30235_ses-d0139_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31245_MR_d0133/anat1/NIFTI/sub-OAS31245_sess-d0133_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31064_MR_d3883/anat3/NIFTI/sub-OAS31064_ses-d3883_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30818_MR_d1228/anat2/NIFTI/sub-OAS30818_ses-d1228_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30096_MR_d2948/anat3/NIFTI/sub-OAS30096_sess-d2948_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30788_MR_d4108/anat3/NIFTI/sub-OAS30788_sess-d4108_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30763_MR_d0112/anat4/NIFTI/sub-OAS30763_ses-d0112_run-02_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30089_MR_d0001/anat3/NIFTI/sub-OAS30089_ses-d0001_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30997_MR_d1356/anat1/NIFTI/sub-OAS30997_ses-d1356_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31274_MR_d0130/anat1/NIFTI/sub-OAS31274_sess-d0130_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30766_MR_d1169/anat1/NIFTI/sub-OAS30766_sess-d1169_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30090_MR_d1294/anat1/NIFTI/sub-OAS30090_ses-d1294_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30756_MR_d1267/anat1/NIFTI/sub-OAS30756_ses-d1267_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30178_MR_d2443/anat2/NIFTI/sub-OAS30178_ses-d2443_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31247_MR_d0110/anat1/NIFTI/sub-OAS31247_sess-d0110_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30403_MR_d1232/anat2/NIFTI/sub-OAS30403_ses-d1232_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30253_MR_d3490/anat2/NIFTI/sub-OAS30253_ses-d3490_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30484_MR_d1065/anat3/NIFTI/sub-OAS30484_ses-d1065_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30324_MR_d0959/anat3/NIFTI/sub-OAS30324_ses-d0959_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31372_MR_d1245/anat1/NIFTI/sub-OAS31372_sess-d1245_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30824_MR_d0077/anat3/NIFTI/sub-OAS30824_ses-d0077_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31462_MR_d0107/anat3/NIFTI/sub-OAS31462_sess-d0107_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30364_MR_d0110/anat3/NIFTI/sub-OAS30364_ses-d0110_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31331_MR_d0175/anat1/NIFTI/sub-OAS31331_sess-d0175_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31436_MR_d0197/anat1/NIFTI/sub-OAS31436_sess-d0197_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31382_MR_d0089/anat3/NIFTI/sub-OAS31382_sess-d0089_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30960_MR_d2110/anat2/NIFTI/sub-OAS30960_ses-d2110_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30914_MR_d0108/anat1/NIFTI/sub-OAS30914_ses-d0108_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30335_MR_d2783/anat1/NIFTI/sub-OAS30335_ses-d2783_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30241_MR_d1706/anat2/NIFTI/sub-OAS30241_ses-d1706_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31282_MR_d0036/anat1/NIFTI/sub-OAS31282_sess-d0036_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30250_MR_d3004/anat3/NIFTI/sub-OAS30250_sess-d3004_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30580_MR_d2664/anat3/NIFTI/sub-OAS30580_sess-d2664_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31153_MR_d0777/anat5/NIFTI/sub-OAS31153_ses-d0777_run-02_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31351_MR_d0008/anat1/NIFTI/sub-OAS31351_sess-d0008_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30005_MR_d3453/anat3/NIFTI/sub-OAS30005_ses-d3453_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30559_MR_d1236/anat2/NIFTI/sub-OAS30559_ses-d1236_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30283_MR_d2660/anat1/NIFTI/sub-OAS30283_sess-d2660_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30249_MR_d1952/anat2/NIFTI/sub-OAS30249_ses-d1952_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31158_MR_d2481/anat3/NIFTI/sub-OAS31158_ses-d2481_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30010_MR_d1514/anat1/NIFTI/sub-OAS30010_sess-d1514_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30038_MR_d5769/anat3/NIFTI/sub-OAS30038_sess-d5769_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30240_MR_d3487/anat3/NIFTI/sub-OAS30240_ses-d3487_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30028_MR_d1847/anat3/NIFTI/sub-OAS30028_ses-d1847_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31092_MR_d3113/anat2/NIFTI/sub-OAS31092_ses-d3113_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30871_MR_d0040/anat2/NIFTI/sub-OAS30871_ses-d0040_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30668_MR_d3574/anat3/NIFTI/sub-OAS30668_sess-d3574_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30006_MR_d4440/anat1/NIFTI/sub-OAS30006_sess-d4440_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30978_MR_d0425/anat3/NIFTI/sub-OAS30978_ses-d0425_FLAIR.nii.gz
# ...
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31118_MR_d2847/anat3/NIFTI/sub-OAS31118_ses-d2847_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30537_MR_d1414/anat3/NIFTI/sub-OAS30537_ses-d1414_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30978_MR_d0059/anat3/NIFTI/sub-OAS30978_ses-d0059_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30220_MR_d1165/anat1/NIFTI/sub-OAS30220_ses-d1165_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31087_MR_d2421/anat3/NIFTI/sub-OAS31087_ses-d2421_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30779_MR_d0065/anat3/NIFTI/sub-OAS30779_ses-d0065_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31469_MR_d0105/anat1/NIFTI/sub-OAS31469_sess-d0105_FLAIR.nii.gz
# Loading dataset: 100%|██████████| 119/119 [01:06<00:00,  1.80it/s]
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30671_MR_d3613/anat1/NIFTI/sub-OAS30671_ses-d3613_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31373_MR_d0133/anat4/NIFTI/sub-OAS31373_sess-d0133_run-02_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30109_MR_d2320/anat7/NIFTI/sub-OAS30109_ses-d2320_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30584_MR_d0096/anat3/NIFTI/sub-OAS30584_ses-d0096_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30132_MR_d1392/anat2/NIFTI/sub-OAS30132_ses-d1392_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31433_MR_d0061/anat1/NIFTI/sub-OAS31433_sess-d0061_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31114_MR_d3002/anat3/NIFTI/sub-OAS31114_ses-d3002_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30219_MR_d1184/anat3/NIFTI/sub-OAS30219_ses-d1184_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30705_MR_d2185/anat3/NIFTI/sub-OAS30705_sess-d2185_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30002_MR_d1680/anat2/NIFTI/sub-OAS30002_sess-d1680_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31065_MR_d0034/anat2/NIFTI/sub-OAS31065_ses-d0034_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31283_MR_d0344/anat1/NIFTI/sub-OAS31283_sess-d0344_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30647_MR_d2394/anat1/NIFTI/sub-OAS30647_sess-d2394_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31041_MR_d1426/anat3/NIFTI/sub-OAS31041_ses-d1426_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31412_MR_d0137/anat3/NIFTI/sub-OAS31412_sess-d0137_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30794_MR_d6661/anat1/NIFTI/sub-OAS30794_sess-d6661_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30109_MR_d4518/anat1/NIFTI/sub-OAS30109_sess-d4518_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30419_MR_d2360/anat2/NIFTI/sub-OAS30419_ses-d2360_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30754_MR_d0019/anat2/NIFTI/sub-OAS30754_sess-d0019_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30822_MR_d2022/anat3/NIFTI/sub-OAS30822_ses-d2022_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30080_MR_d0048/anat2/NIFTI/sub-OAS30080_ses-d0048_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30127_MR_d0110/anat3/NIFTI/sub-OAS30127_ses-d0110_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31333_MR_d0023/anat2/NIFTI/sub-OAS31333_sess-d0023_run-02_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31293_MR_d0084/anat3/NIFTI/sub-OAS31293_sess-d0084_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30168_MR_d1268/anat2/NIFTI/sub-OAS30168_ses-d1268_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31209_MR_d0095/anat3/NIFTI/sub-OAS31209_sess-d0095_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31334_MR_d0088/anat3/NIFTI/sub-OAS31334_sess-d0088_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30229_MR_d0101/anat3/NIFTI/sub-OAS30229_ses-d0101_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30093_MR_d0056/anat3/NIFTI/sub-OAS30093_ses-d0056_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30715_MR_d1230/anat4/NIFTI/sub-OAS30715_ses-d1230_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31356_MR_d0091/anat3/NIFTI/sub-OAS31356_sess-d0091_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30185_MR_d4551/anat3/NIFTI/sub-OAS30185_ses-d4551_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31153_MR_d2282/anat2/NIFTI/sub-OAS31153_ses-d2282_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30427_MR_d5636/anat1/NIFTI/sub-OAS30427_sess-d5636_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30749_MR_d1996/anat3/NIFTI/sub-OAS30749_ses-d1996_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30979_MR_d0435/anat3/NIFTI/sub-OAS30979_ses-d0435_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30367_MR_d3396/anat3/NIFTI/sub-OAS30367_ses-d3396_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30221_MR_d2358/anat5/NIFTI/sub-OAS30221_sess-d2358_run-02_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30007_MR_d1636/anat3/NIFTI/sub-OAS30007_ses-d1636_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30579_MR_d0112/anat2/NIFTI/sub-OAS30579_sess-d0112_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30723_MR_d2278/anat3/NIFTI/sub-OAS30723_ses-d2278_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30123_MR_d0122/anat3/NIFTI/sub-OAS30123_ses-d0122_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30462_MR_d1232/anat3/NIFTI/sub-OAS30462_ses-d1232_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30322_MR_d5194/anat1/NIFTI/sub-OAS30322_sess-d5194_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30960_MR_d3518/anat2/NIFTI/sub-OAS30960_ses-d3518_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31001_MR_d4543/anat3/NIFTI/sub-OAS31001_sess-d4543_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30228_MR_d0090/anat3/NIFTI/sub-OAS30228_ses-d0090_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30933_MR_d3460/anat1/NIFTI/sub-OAS30933_sess-d3460_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31104_MR_d3744/anat1/NIFTI/sub-OAS31104_sess-d3744_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30581_MR_d3917/anat1/NIFTI/sub-OAS30581_ses-d3917_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31058_MR_d2233/anat2/NIFTI/sub-OAS31058_ses-d2233_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30248_MR_d2017/anat3/NIFTI/sub-OAS30248_sess-d2017_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31020_MR_d0084/anat3/NIFTI/sub-OAS31020_ses-d0084_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31175_MR_d0069/anat3/NIFTI/sub-OAS31175_sess-d0069_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31217_MR_d0118/anat3/NIFTI/sub-OAS31217_sess-d0118_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30484_MR_d0069/anat2/NIFTI/sub-OAS30484_ses-d0069_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31214_MR_d0077/anat3/NIFTI/sub-OAS31214_sess-d0077_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30667_MR_d0888/anat3/NIFTI/sub-OAS30667_ses-d0888_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30978_MR_d1207/anat2/NIFTI/sub-OAS30978_ses-d1207_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30821_MR_d0068/anat3/NIFTI/sub-OAS30821_ses-d0068_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30004_MR_d2229/anat2/NIFTI/sub-OAS30004_ses-d2229_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31349_MR_d0048/anat1/NIFTI/sub-OAS31349_sess-d0048_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30221_MR_d0079/anat2/NIFTI/sub-OAS30221_ses-d0079_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30075_MR_d0442/anat3/NIFTI/sub-OAS30075_ses-d0442_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31409_MR_d0042/anat1/NIFTI/sub-OAS31409_sess-d0042_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31114_MR_d3479/anat2/NIFTI/sub-OAS31114_ses-d3479_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30996_MR_d5818/anat1/NIFTI/sub-OAS30996_sess-d5818_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30910_MR_d1028/anat3/NIFTI/sub-OAS30910_ses-d1028_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30452_MR_d4501/anat3/NIFTI/sub-OAS30452_ses-d4501_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31070_MR_d1352/anat1/NIFTI/sub-OAS31070_sess-d1352_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30062_MR_d1745/anat2/NIFTI/sub-OAS30062_ses-d1745_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30612_MR_d1201/anat2/NIFTI/sub-OAS30612_ses-d1201_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30808_MR_d3453/anat3/NIFTI/sub-OAS30808_ses-d3453_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31115_MR_d0466/anat1/NIFTI/sub-OAS31115_ses-d0466_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31110_MR_d2336/anat3/NIFTI/sub-OAS31110_ses-d2336_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30194_MR_d8874/anat3/NIFTI/sub-OAS30194_ses-d8874_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30612_MR_d1792/anat3/NIFTI/sub-OAS30612_sess-d1792_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30025_MR_d2298/anat3/NIFTI/sub-OAS30025_ses-d2298_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30608_MR_d5006/anat1/NIFTI/sub-OAS30608_sess-d5006_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30492_MR_d0090/anat2/NIFTI/sub-OAS30492_ses-d0090_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31199_MR_d0111/anat1/NIFTI/sub-OAS31199_sess-d0111_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30422_MR_d0104/anat1/NIFTI/sub-OAS30422_ses-d0104_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31232_MR_d0124/anat1/NIFTI/sub-OAS31232_sess-d0124_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30982_MR_d1708/anat3/NIFTI/sub-OAS30982_ses-d1708_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30832_MR_d3848/anat1/NIFTI/sub-OAS30832_sess-d3848_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30542_MR_d3906/anat1/NIFTI/sub-OAS30542_sess-d3906_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30770_MR_d0255/anat2/NIFTI/sub-OAS30770_ses-d0255_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30139_MR_d1702/anat3/NIFTI/sub-OAS30139_ses-d1702_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30974_MR_d0901/anat1/NIFTI/sub-OAS30974_ses-d0901_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31123_MR_d0078/anat3/NIFTI/sub-OAS31123_ses-d0078_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30945_MR_d0155/anat3/NIFTI/sub-OAS30945_ses-d0155_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31031_MR_d1861/anat2/NIFTI/sub-OAS31031_ses-d1861_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31104_MR_d1321/anat2/NIFTI/sub-OAS31104_ses-d1321_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30548_MR_d0447/anat3/NIFTI/sub-OAS30548_ses-d0447_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31390_MR_d0060/anat2/NIFTI/sub-OAS31390_sess-d0060_run-02_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31398_MR_d0098/anat3/NIFTI/sub-OAS31398_sess-d0098_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31186_MR_d0102/anat3/NIFTI/sub-OAS31186_sess-d0102_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31236_MR_d0048/anat1/NIFTI/sub-OAS31236_sess-d0048_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30113_MR_d3502/anat2/NIFTI/sub-OAS30113_ses-d3502_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30027_MR_d2394/anat2/NIFTI/sub-OAS30027_ses-d2394_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30522_MR_d0103/anat3/NIFTI/sub-OAS30522_ses-d0103_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30816_MR_d4583/anat1/NIFTI/sub-OAS30816_sess-d4583_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30769_MR_d1547/anat2/NIFTI/sub-OAS30769_ses-d1547_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31018_MR_d0045/anat3/NIFTI/sub-OAS31018_ses-d0045_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30465_MR_d1030/anat3/NIFTI/sub-OAS30465_sess-d1030_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30079_MR_d2668/anat3/NIFTI/sub-OAS30079_ses-d2668_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30656_MR_d2737/anat1/NIFTI/sub-OAS30656_ses-d2737_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30013_MR_d0102/anat3/NIFTI/sub-OAS30013_ses-d0102_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30959_MR_d4116/anat3/NIFTI/sub-OAS30959_sess-d4116_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30496_MR_d2304/anat1/NIFTI/sub-OAS30496_sess-d2304_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31316_MR_d0061/anat3/NIFTI/sub-OAS31316_sess-d0061_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30170_MR_d0005/anat2/NIFTI/sub-OAS30170_ses-d0005_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30410_MR_d0034/anat3/NIFTI/sub-OAS30410_ses-d0034_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30443_MR_d1480/anat2/NIFTI/sub-OAS30443_ses-d1480_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30866_MR_d1502/anat3/NIFTI/sub-OAS30866_sess-d1502_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31267_MR_d0090/anat3/NIFTI/sub-OAS31267_sess-d0090_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31054_MR_d2787/anat3/NIFTI/sub-OAS31054_ses-d2787_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30725_MR_d1182/anat4/NIFTI/sub-OAS30725_ses-d1182_run-02_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30710_MR_d1179/anat2/NIFTI/sub-OAS30710_ses-d1179_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31047_MR_d1165/anat2/NIFTI/sub-OAS31047_ses-d1165_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30901_MR_d0155/anat1/NIFTI/sub-OAS30901_ses-d0155_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30571_MR_d3528/anat3/NIFTI/sub-OAS30571_sess-d3528_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30863_MR_d4148/anat1/NIFTI/sub-OAS30863_ses-d4148_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31120_MR_d0119/anat7/NIFTI/sub-OAS31120_ses-d0119_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30620_MR_d2211/anat3/NIFTI/sub-OAS30620_ses-d2211_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30754_MR_d3556/anat1/NIFTI/sub-OAS30754_sess-d3556_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30445_MR_d1279/anat3/NIFTI/sub-OAS30445_sess-d1279_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30667_MR_d0502/anat3/NIFTI/sub-OAS30667_ses-d0502_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31338_MR_d0091/anat1/NIFTI/sub-OAS31338_sess-d0091_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30769_MR_d2231/anat3/NIFTI/sub-OAS30769_ses-d2231_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30009_MR_d3534/anat3/NIFTI/sub-OAS30009_sess-d3534_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS31301_MR_d0085/anat3/NIFTI/sub-OAS31301_sess-d0085_FLAIR.nii.gz
# /content/drive/MyDrive/OASIS-3-MR-Sessions-2D/OAS30483_MR_d2290/anat1/NIFTI/sub-OAS30483_sess-d2290_FLAIR.nii.gz
# Loading dataset: 100%|██████████| 13/13 [00:05<00:00,  2.54it/s]

# %%
dataiter = iter(train_loader)
batch_sample = next(dataiter)
images = batch_sample["image"]
labels = batch_sample["label"]

classes = ["HC", "AD"]

plt.figure(figsize=(20, 12))
i = 0
for sample_data, sample_label in zip(images, labels):
    sample = sample_data.cpu()[0]
    plt.subplot(1, batch_size, i+1)  # Create a subplot for each sample
    plt.imshow(sample.T, cmap='gray', origin='lower')
    plt.title(f"{classes[int(sample_label.cpu()[0])]}")  # Display the label as the title
    i += 1
plt.show()

# %%
out_model_dir = r"/content/drive/MyDrive/M3AE_N/pretrained"
model_file_name = f"m3ae_unimodal_oasis_3_{str(modality).split('.')[1]}.pth"

# %%
# This is an MAE model trained with pixels as targets for visualization (ViT-Large, training mask ratio=0.75)

# download checkpoint if not exist
# !wget -nc https://dl.fbaipublicfiles.com/mae/visualize/mae_visualize_vit_large.pth

chkpt_dir = 'mae_visualize_vit_large.pth'
model_mae = prepare_model(chkpt_dir, 'mae_vit_large_patch16')
print('Model loaded.')
# Out:
# --2023-09-17 17:16:38--  https://dl.fbaipublicfiles.com/mae/visualize/mae_visualize_vit_large.pth
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 13.35.7.128, 13.35.7.38, 13.35.7.82, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|13.35.7.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1318315181 (1.2G) [binary/octet-stream]
# Saving to: ‘mae_visualize_vit_large.pth’
#
# mae_visualize_vit_l 100%[===================>]   1.23G   153MB/s    in 9.0s
#
# 2023-09-17 17:16:47 (139 MB/s) - ‘mae_visualize_vit_large.pth’ saved [1318315181/1318315181]
#
# <All keys matched successfully>
# Model loaded.

# %%
model_mae
# Out:
# MaskedAutoencoderViT(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 1024, kernel_size=(16, 16), stride=(16, 16))
#   )
#   (blocks): ModuleList(
#     (0-23): 24 x Block(
#       (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=1024, out_features=1024, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#   )
#   (norm): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#   (decoder_embed): Linear(in_features=1024, out_features=512, bias=True)
#   (decoder_blocks): ModuleList(
#     (0-7): 8 x Block(
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#   )
#   (decoder_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#   (decoder_pred): Linear(in_features=512, out_features=768, bias=True)
# )

# %%
from einops import repeat, rearrange
class ViT_Classifier(torch.nn.Module):
    def __init__(self, mae, num_classes=1) -> None:
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(1, 3, kernel_size=1, stride=1, padding=0, bias=False),
            nn.ReLU(),
            nn.BatchNorm2d(3)
        )
        self.mae = mae
        self.head = torch.nn.Linear(mae.pos_embed.shape[-1], num_classes)

    def forward(self, img):
        img = self.conv(img)
        features, mask, ids_restore = self.mae.forward_encoder(img, 0)
        features = rearrange(features, 'b t c -> t b c')
        logits = self.head(features[0])
        return logits
chkpt_dir = 'mae_visualize_vit_large.pth'
model_mae = prepare_model(chkpt_dir, 'mae_vit_large_patch16').cuda()
print('Model loaded.')
model = ViT_Classifier(model_mae).cuda()
# x = torch.ones([2,1,224,224]).cuda()
# print(model(x).shape)
# Out:
# <All keys matched successfully>
# Model loaded.

# %%
model = model.to(device)
criterion = torch.nn.BCEWithLogitsLoss()
scaler = torch.cuda.amp.GradScaler()
# optimizer = optim.SGD(model.parameters(), lr=0.0001, momentum=0.9)
optimizer = optim.Adam(model.parameters(), lr=1e-5)
val_interval = 1
auc_metric = ROCAUCMetric()

# %%
from tqdm import tqdm
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = []
metric_values = []

y_pred_trans = Compose([Activations(sigmoid=True)])
max_epochs = 10
for epoch in range(max_epochs):
    print("-" * 10)
    print(f"epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss = 0
    step = 0
    for batch_data in tqdm(train_loader):
        step += 1
        inputs, labels = batch_data["image"].to(device).float(), batch_data["label"].to(device).float()
        optimizer.zero_grad()
        with torch.cuda.amp.autocast():
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            # print(outputs)
            # print(loss)
        # loss.backward()
        # optimizer.step()
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        epoch_loss += loss.item()
        # print(f"{step}/{len(train_ds) // train_loader.batch_size}, " f"train_loss: {loss.item():.4f}")
        epoch_len = len(train_ds) // train_loader.batch_size
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    if (epoch + 1) % val_interval == 0:
        model.eval()
        with torch.no_grad():
            y_pred = torch.tensor([], dtype=torch.float32, device=device)
            y = torch.tensor([], dtype=torch.long, device=device)
            for val_data in tqdm(val_loader):
                val_images, val_labels = (
                    val_data["image"].to(device),
                    val_data["label"].to(device),
                )
                y_pred = torch.cat([y_pred, model(val_images)], dim=0)
                y = torch.cat([y, val_labels], dim=0)
            y_onehot = torch.cat([i for i in decollate_batch(y, detach=False)], dim=0)
            y_pred_act = torch.cat([y_pred_trans(i) for i in decollate_batch(y_pred)], dim=0)
            auc_metric(y_pred_act, y_onehot)
            result = auc_metric.aggregate()
            auc_metric.reset()
            metric_values.append(result)
            acc_value = torch.eq((y_pred_act > 0.5).long(), y)
            acc_metric = acc_value.float().mean().item()
            del y_pred_act, y_onehot
            if result > best_metric:
                best_metric = result
                best_metric_epoch = epoch + 1
                torch.save(model.state_dict(), os.path.join(out_model_dir, model_file_name))
                print("saved new best metric model")
            print(
                f"current epoch: {epoch + 1} current AUC: {result:.4f}"
                f" current accuracy: {acc_metric:.4f}"
                f" best AUC: {best_metric:.4f}"
                f" at epoch: {best_metric_epoch}"
            )

print(f"train completed, best_metric (AUC): {best_metric:.4f} " f"at epoch: {best_metric_epoch}")
# Out:
# ----------
# epoch 1/10
# 100%|██████████| 75/75 [23:31<00:00, 18.82s/it]
# epoch 1 average loss: 0.3406
# 100%|██████████| 9/9 [02:32<00:00, 16.99s/it]
# saved new best metric model
# current epoch: 1 current AUC: 0.7591 current accuracy: 0.8797 best AUC: 0.7591 at epoch: 1
# ----------
# epoch 2/10
# 100%|██████████| 75/75 [00:34<00:00,  2.17it/s]
# epoch 2 average loss: 0.2739
# 100%|██████████| 9/9 [00:02<00:00,  3.34it/s]
# saved new best metric model
# current epoch: 2 current AUC: 0.7895 current accuracy: 0.8797 best AUC: 0.7895 at epoch: 2
# ----------
# epoch 3/10
# 100%|██████████| 75/75 [00:37<00:00,  2.01it/s]
# epoch 3 average loss: 0.2186
# 100%|██████████| 9/9 [00:02<00:00,  3.36it/s]
# saved new best metric model
# current epoch: 3 current AUC: 0.8093 current accuracy: 0.8740 best AUC: 0.8093 at epoch: 3
# ----------
# epoch 4/10
# 100%|██████████| 75/75 [00:36<00:00,  2.04it/s]
# epoch 4 average loss: 0.1489
# 100%|██████████| 9/9 [00:02<00:00,  3.39it/s]
# current epoch: 4 current AUC: 0.8056 current accuracy: 0.8454 best AUC: 0.8093 at epoch: 3
# ----------
# epoch 5/10
# 100%|██████████| 75/75 [00:34<00:00,  2.19it/s]
# epoch 5 average loss: 0.0875
# 100%|██████████| 9/9 [00:02<00:00,  3.37it/s]
# current epoch: 5 current AUC: 0.7847 current accuracy: 0.7998 best AUC: 0.8093 at epoch: 3
# ----------
# epoch 6/10
# 100%|██████████| 75/75 [00:34<00:00,  2.20it/s]
# epoch 6 average loss: 0.0511
# 100%|██████████| 9/9 [00:02<00:00,  3.32it/s]
# current epoch: 6 current AUC: 0.7516 current accuracy: 0.8112 best AUC: 0.8093 at epoch: 3
# ----------
# epoch 7/10
# 100%|██████████| 75/75 [00:33<00:00,  2.23it/s]
# epoch 7 average loss: 0.0302
# 100%|██████████| 9/9 [00:02<00:00,  3.46it/s]
# current epoch: 7 current AUC: 0.6405 current accuracy: 0.8683 best AUC: 0.8093 at epoch: 3
# ----------
# epoch 8/10
# 100%|██████████| 75/75 [00:34<00:00,  2.20it/s]
# epoch 8 average loss: 0.0157
# 100%|██████████| 9/9 [00:02<00:00,  3.43it/s]
# saved new best metric model
# current epoch: 8 current AUC: 0.8221 current accuracy: 0.8569 best AUC: 0.8221 at epoch: 8
# ----------
# epoch 9/10
# 100%|██████████| 75/75 [00:34<00:00,  2.15it/s]
# epoch 9 average loss: 0.0130
# 100%|██████████| 9/9 [00:02<00:00,  3.40it/s]
# current epoch: 9 current AUC: 0.7249 current accuracy: 0.8626 best AUC: 0.8221 at epoch: 8
# ----------
# epoch 10/10
# 100%|██████████| 75/75 [00:33<00:00,  2.21it/s]
# epoch 10 average loss: 0.0055
# 100%|██████████| 9/9 [00:02<00:00,  3.34it/s]
# current epoch: 10 current AUC: 0.7372 current accuracy: 0.8569 best AUC: 0.8221 at epoch: 8
# train completed, best_metric (AUC): 0.8221 at epoch: 8
