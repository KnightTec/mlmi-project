# %%
import numpy as np
import matplotlib.pyplot as plt
 
  
# creating the dataset
data = {'Decision Product':0.7757, 'Decision Max':0.7763, 'Input Zeros':0.8003, 'Input Gauss':0.7966, "Input Gating": 0.8027}
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (7, 6))
 
# creating the bar plot
plt.bar(courses, values, width = 0.6)

plt.ylim(0.75, 0.82)
 
plt.xlabel("Fusion Methods")
plt.ylabel("Mean AUC")
plt.title("Fusion Method Average Performance")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
 
  
# creating the dataset
data = {'T1':0.014, 'T2':0.0152, 'T2*':0.0028, 'FLAIR':0.0007, "TOF MRA": -0.0197}
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (7, 6))
 
# creating the bar plot
plt.bar(courses, values, width = 0.6)

 
plt.xlabel("MR Modalites")
plt.ylabel("Avg AUC difference w/ and w/o modality")
plt.title("Modality impact on AD classification")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
 
  
# creating the dataset
data = {'T1':4116, 'T2':4051, 'T2*':4051, 'FLAIR':1381, "TOF MRA": 896}
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (7, 6))
 
# creating the bar plot
plt.bar(courses, values, width = 0.6)

i = 0
for key, value in data.items():
    plt.text(i, value + 50, value, ha = 'center')
    i += 1
 
plt.xlabel("MR Modalites")
plt.ylabel("Scan Count")
plt.title("Number of sMRI scans in OASIS-3 w/ duplicate modalities")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
 
  
# creating the dataset
data = {'T1':4110, 'T2':4043, 'T2*':2345, 'FLAIR':1379, "TOF MRA": 893}
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (7, 6))
 
# creating the bar plot
plt.bar(courses, values, width = 0.6)

i = 0
for key, value in data.items():
    plt.text(i, value + 50, value, ha = 'center')
    i += 1
 
plt.xlabel("MR Modalites")
plt.ylabel("Scan Count")
plt.title("Total Number of sMRI scans in OASIS-3")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
 
  
# creating the dataset
data = {'T1':3501, 'T2':3672, 'T2*':2345, 'FLAIR':1379, "TOF MRA": 893}
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (7, 6))
 
# creating the bar plot
plt.bar(courses, values, width = 0.6)

i = 0
for key, value in data.items():
    plt.text(i, value + 50, value, ha = 'center')
    i += 1
 
plt.xlabel("MR Modalites")
plt.ylabel("Scan Count")
plt.title("Modalities in preprocessed OASIS-3 dataset")
plt.show()

# %%
import pandas as pd

df = pd.read_csv("./csv/oasis/oasis_3_multimodal_full.csv", sep=";")

data = {'Healthy': (df["cdr"] == 0).sum(), 'Alzheimers\' Disease':(df["cdr"] > 0).sum()}
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (7, 6))
 
# creating the bar plot
plt.bar(courses, values, width = 0.6)

i = 0
for key, value in data.items():
    plt.text(i, value + 50, value, ha = 'center')
    i += 1
 
plt.xlabel("Label")
plt.ylabel("Session Count")
plt.title("OASIS-3 Labels")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


df = pd.read_csv("csv/oasis/oasis_3_mulitmodal_full.csv", sep=";")
df.fillna('', inplace=True)

t1_count = df['MR T1w'].apply(lambda x: len(x.strip()) > 0).sum()
t2_count = df['MR T2w'].apply(lambda x: len(x.strip()) > 0).sum()
t2_star_count = df['MR T2*'].apply(lambda x: len(x.strip()) > 0).sum()
flair_count = df['MR FLAIR'].apply(lambda x: len(x.strip()) > 0).sum()
tof_mra_count = df['MR TOF-MRA'].apply(lambda x: len(x.strip()) > 0).sum()


# creating the dataset
data = {'T1':t1_count, 'T2':t2_count, 'T2*':t2_star_count, 'FLAIR':flair_count, "TOF MRA": tof_mra_count}
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (7, 6))
 
# creating the bar plot
plt.bar(courses, values, width = 0.6)

i = 0
for key, value in data.items():
    plt.text(i, value + 50, value, ha = 'center')
    i += 1
 
plt.xlabel("MR Modalites")
plt.ylabel("Scan Count")
plt.title("Number of sMRI scans in OASIS-3 w/o duplicate modalities")
plt.show()
